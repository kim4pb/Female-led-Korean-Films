# %%
import pandas as pd

df = pd.read_csv('../01.Data_Collection/films.csv')

# %%
df.columns
# Out:
# Index(['F-rated', '감독', '감독_대표역할', '감독성별', '감독코드', '감독필모', '개봉일', '관객수', '국적',
#        '누적관객수', '누적매출액', '대표감독', '대표국적', '대표작가', '대표작가(필명)', '등급', '매출액',
#        '매출액점유율', '배급사', '배역명', '배우', '배우_대표역할', '배우성별', '배우코드', '배우필모', '상영횟수',
#        '순위', '스크린수', '영화명', '영화코드', '작가', '작가_대표역할', '작가성별', '작가코드', '작가필모',
#        '장르', '제작사', '주연배우'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 38

# %%
column_list = ['순위', '영화명', '영화코드', '개봉일', '매출액', '매출액점유율', '누적매출액', '관객수', '누적관객수', 
               '스크린수', '상영횟수', '대표국적', '국적', '제작사', '배급사', '등급', '장르', 'F-rated',
               '감독', '대표감독', '감독코드', '감독성별', '감독_대표역할', '감독필모',
               '작가', '대표작가', '대표작가(필명)', '작가코드', '작가성별', '작가_대표역할', '작가필모',  
               '배우', '주연배우', '배역명', '배우코드', '배우성별', '배우_대표역할', '배우필모']

df = df[column_list]

# %%
df.head()
# Out:
#       순위       영화명      영화코드         개봉일           매출액 매출액점유율         누적매출액  \
# 0   55.0       워킹걸  20147947  2015-01-07  1.183887e+09   0.1%  1.201963e+09
# 1  121.0        설해  20124398  2015-01-08  2.076750e+07   0.0%  2.977050e+07
# 2   26.0       허삼관  20131262  2015-01-14  7.408944e+09   0.8%  7.408944e+09
# 3   16.0    오늘의 연애  20142407  2015-01-14  1.492465e+10   1.7%  1.492465e+10
# 4  149.0  꽃보다 처녀귀신  20155744  2015-01-15  7.909000e+06   0.0%  7.909000e+06
#
#          관객수      누적관객수   스크린수  ...  작가성별 작가_대표역할  \
# 0   149181.0   151550.0  308.0  ...    남자      감독
# 1     2796.0     3933.0   34.0  ...    남자      감독
# 2   955679.0   955679.0  621.0  ...    남자      배우
# 3  1891993.0  1891993.0  709.0  ...    남자      감독
# 4     1567.0     1567.0    5.0  ...    남자      감독
#
#                                                 작가필모  \
# 0  공포체험단 곤지암편|천문: 하늘에 묻는다|곤지암|워킹걸|미쓰GO|외톨이|기담|무서운...
# 1                설해|그 남자의 책 198쪽|바보|화성으로 간 사나이|동감|귀소
# 2  백두산|PMC: 더 벙커|클로젯|신과함께-인과 연|1987|신과함께-죄와 벌|서서평...
# 3  오늘의 연애|공범|내 사랑 내 곁에|그놈 목소리|너는 내 운명|죽어도 좋아|신비한 ...
# 4              꽃보다 처녀귀신|태양의 이면|바이칼|바르도|삼승할망|좀비처럼 걸어봐
#
#                                                   배우 주연배우  배역명        배우코드  \
# 0  조여정,클라라,김태우,배유람,정범식,정범식,박주희,백경인,조은영,손진우,배성우,유찬...  조여정  NaN  10066680.0
# 1  박해진,이영아,송재희,전무송,최원주,이상민,이기열,윤기호,김수환,김정권,김혜진,박재...  박해진   상우  20126329.0
# 2  하정우,하지원,전혜진,장광,주진모,성동일,이경영,김영애,정만식,조진웅,김기천,김성균...  하정우  허삼관  10087253.0
# 3  이승기,문채원,이서진,장진우,이경진,이동진,임하룡,이상협,김광규,김부선,가인,임종윤...  이승기  NaN  10056227.0
# 4  안재민,이정민,이정민,박승찬,이현복,최경택,손지훈,우경희,유재훈,이돌,하혜정,한상민...  안재민  NaN  20204727.0
#
#    배우성별 배우_대표역할                                               배우필모
# 0    여자      배우            기생충|워킹걸|인간중독|표적|후궁 : 제왕의 첩|방자전|흡혈형사 나도열
# 1    남자      배우                                      치즈인더트랩|설해|젓가락
# 2    남자      배우  백두산|PMC: 더 벙커|클로젯|신과함께-인과 연|1987|신과함께-죄와 벌|서서평...
# 3    남자      배우                                          궁합|오늘의 연애
# 4    남자      배우                                           꽃보다 처녀귀신
#
# [5 rows x 38 columns]

# %%
# df.to_excel('../01.Data_Collection/films.xlsx', index=False)

# %%
df2 = pd.read_excel('../01.Data_Collection/films_edit.xlsx')

# %%
df2.isnull().sum()
# Out:
# 순위            2
# 영화명           0
# 영화코드          0
# 개봉일           0
# 매출액           0
# 매출액점유율        2
# 누적매출액         0
# 관객수           0
# 누적관객수         0
# 스크린수          0
# 상영횟수          0
# 대표국적          0
# 국적            0
# 제작사          21
# 배급사           3
# 등급            2
# 장르            2
# F-rated       0
# 감독            2
# 대표감독          2
# 감독코드          2
# 감독성별          5
# 감독_대표역할       2
# 감독필모          2
# 작가           96
# 대표작가         96
# 대표작가(필명)     96
# 작가코드         96
# 작가성별        130
# 작가_대표역할      96
# 작가필모         96
# 배우            0
# 주연배우          0
# 배역명         445
# 배우코드          0
# 배우성별         16
# 배우_대표역할       0
# 배우필모         69
# dtype: int64

# %%
df2[df2['감독성별'].isnull()]
# Out:
#         순위             영화명      영화코드         개봉일          매출액 매출액점유율  \
# 223   19.0  탐정 홍길동: 사라진 마을  20142406  2016-05-04  11516170845   1.2%
# 348  391.0         맛있는 워킹걸  20179694  2017-02-02       940000   0.0%
# 502   69.0        젝스키스 에이틴  20189525  2018-01-18    364405500   0.0%
# 544  267.0        아버지를 찾아서  20182781  2018-04-12      1262000   0.0%
# 661   84.0          트와이스랜드  20184529  2018-12-07    153765000   0.0%
#
#            누적매출액      관객수    누적관객수  스크린수  ...  작가성별   작가_대표역할  \
# 223  11516170845  1430885  1430885   764  ...   NaN  VFX 아티스트
# 348       940000      214      214    20  ...    여자  시나리오(각본)
# 502    364405500    50419    50419    25  ...   NaN       NaN
# 544      1262000      445      445     7  ...    남자        제작
# 661    153765000    18252    18252    53  ...   NaN       NaN
#
#                                                   작가필모  \
# 223                          도어락|물괴|탐정 홍길동: 사라진 마을|족구왕
# 348  애연|침입자|맛있는 워킹걸|어린 아내|잠 못 이루는 섹스 2|옆집 누나|자유연애시대...
# 502                                                NaN
# 544                                           아버지를 찾아서
# 661                                                NaN
#
#                                                     배우 주연배우     배역명      배우코드  \
# 223  이제훈,김성균,박근형,정성화,고아라,노정의,김하나,유승목,박정원,박지훈,오현암,유정...  이제훈     홍길동  10057349
# 348                                                백지훈  백지훈  봉고차 남자  20287412
# 502                            은지원,이재진,장수원,김재덕,강성훈,이재진  은지원     NaN  10054654
# 544  강병호,김문현,김문현,김민수,김정인,김준기,박노진,이경훈,이상화,장은정,전상진,정재...  강병호     NaN  20303150
# 661                         나연,정연,모모,사나,지효,미나,다현,채영,쯔위   나연     NaN  10072145
#
#      배우성별 배우_대표역할                                               배우필모
# 223    남자      배우  컬렉터|사냥의 시간(가제)|지구: 놀라운 하루|아이 캔 스피크|박열|탐정 홍길동: ...
# 348    남자      배우                                            맛있는 워킹걸
# 502    남자      배우                      젝스키스 에이틴|링스 어드벤처|여고생 시집가기|세븐틴
# 544    남자      배우                                           아버지를 찾아서
# 661    여자      배우                                             트와이스랜드
#
# [5 rows x 38 columns]
