# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../01.Data_Collection/screen_show_seat.csv')
df_up=pd.read_csv('../01.Data_Collection/screen_show_seat_updated.csv')

# %%
# %matplotlib inlinefrom matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
plt.rcParams['font.family'] = 'NanumGothic'
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('float_format', '{:f}'.format)
# Out:
# UsageError: unrecognized arguments: matplotlib import font_manager, rc

# %%
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %% [markdown]
# # 스크린 점유율 순위 1등과 10등 비교.
# - 스크린점유율 순위 1등(장사리)과 10등(리틀포레스트)을 비교했으나, 개봉일이 달라 의미가 있지만 뚜렷한 의미를 보이지 않음.
# - So, 국제시장과 개봉일이 비슷한 1919유관순을 비교하고자 함.

# %%
df_up[df_up['스크린점유율순위']== 1]
# Out:
#        스크린점유율순위       영화명         개봉일  스크린수 스크린점유율         매출액        누적매출액  \
# 0             1      국제시장  2014-12-17   941  35.8%  6129982500  47219550096
# 26            1      국제시장  2014-12-17   930  35.5%  3782877729  51002427825
# 49            1      국제시장  2014-12-17  1044  38.4%  5102642636  56105070461
# 72            1      국제시장  2014-12-17  1026  38.3%  4437089200  60542159661
# 93            1      국제시장  2014-12-17   910  35.9%  1558134100  62100293761
# ...         ...       ...         ...   ...    ...         ...          ...
# 58603         1  82년생 김지영  2019-10-23  1272  73.2%  2447449820  18518294900
# 58644         1  82년생 김지영  2019-10-23  1250  73.1%  2038135690  20556430590
# 58682         1  82년생 김지영  2019-10-23  1195  68.2%   703939330  21260369920
# 58733         1  82년생 김지영  2019-10-23  1197  68.9%   680981950  21941351870
# 58777         1  82년생 김지영  2019-10-23  1211  67.9%   681547850  22622899720
#
# ...

# %%
df_1=df_up[df_up['스크린점유율순위']== 1]

# %%
df_1.groupby(df_1['영화명'])

# %%
df_1['영화명']
# Out:
# 0            국제시장
# 26           국제시장
# 49           국제시장
# 72           국제시장
# 93           국제시장
#            ...
# 58603    82년생 김지영
# 58644    82년생 김지영
# 58682    82년생 김지영
# 58733    82년생 김지영
# 58777    82년생 김지영
# Name: 영화명, Length: 1773, dtype: object

# %%
df_1.drop_duplicates('영화명', keep='first')
# Out:
#        스크린점유율순위               영화명         개봉일  스크린수 스크린점유율         매출액  \
# 0             1              국제시장  2014-12-17   941  35.8%  6129982500
# 557           1           강남 1970  2015-01-21   684  29.5%  1184775700
# 1045          1               쎄시봉  2015-02-05   757  31.7%   713911500
# 1252          1  조선명탐정 : 사라진 놉의 딸  2015-02-11   740  34.1%   853823300
# 1846          1            순수의 시대  2015-03-05   512  33.8%   463897100
# ...         ...               ...         ...   ...    ...         ...
# 56260         1       타짜: 원 아이드 잭  2019-09-11  1345  25.8%  2693258790
# 56376         1      나쁜 녀석들: 더 무비  2019-09-11  1483  25.4%  6744962562
# 56835         1     장사리 : 잊혀진 영웅들  2019-09-25  1065  28.2%   770367470
# 57141         1         가장 보통의 연애  2019-10-02  1006  25.3%  1152655840
# 58108         1          82년생 김지영  2019-10-23  1354  47.4%  1105980170
#
#              누적매출액     관객수    누적관객수      점유율집계일  좌석판매점유율순위  좌석판매율   좌석점유율  \
# ...

# %%
df_10=df_up[df_up['스크린점유율순위']== 10]

# %%
df_10.drop_duplicates('영화명', keep='last')
# Out:
#        스크린점유율순위           영화명         개봉일  스크린수 스크린점유율       매출액        누적매출액  \
# 218          10            목숨  2014-12-04    10   0.4%    474000    280449600
# 916          10          쿼바디스  2014-12-10     4   0.2%    134000    151911500
# 1150         10           허삼관  2015-01-14    16   0.6%   3622900   7398397569
# 1481         10  어우동: 주인 없는 꽃  2015-01-29     2   0.1%     22000     67127000
# 1482         10        오늘의 연애  2015-01-14     2   0.1%    438800  14923424487
# ...         ...           ...         ...   ...    ...       ...          ...
# 58742        10  나쁜 녀석들: 더 무비  2019-09-11     6   0.3%    605000  39552786124
# 58743        10          블랙머니  2019-11-13     6   0.3%  12284000    163931500
# 58744        10      북간도의 십자가  2019-10-17     6   0.3%    207500     48136880
# 58745        10          윤희에게  2019-11-14     6   0.3%  12240000     12240000
# 58786        10         두번할까요  2019-10-17    12   0.7%    377000   1437757120
#
# ...

# %%
df_10.drop_duplicates('영화명', keep='first')
# Out:
#        스크린점유율순위             영화명         개봉일  스크린수 스크린점유율       매출액  \
# 9            10  그 사람 그 사랑 그 세상  2014-11-20     7   0.3%   9467000
# 58           10            다이빙벨  2014-10-23     5   0.2%    494000
# 128          10             워킹걸  2015-01-07     5   0.2%   9901000
# 185          10          오늘의 연애  2015-01-14     9   0.4%  32176000
# 218          10              목숨  2014-12-04    10   0.4%    474000
# ...         ...             ...         ...   ...    ...       ...
# 58281        10             도둑들  2012-07-25    16   0.6%    614000
# 58478        10        북간도의 십자가  2019-10-17     8   0.4%    289000
# 58691        10          오늘, 우리  2019-10-31    11   0.6%    181300
# 58743        10            블랙머니  2019-11-13     6   0.3%  12284000
# 58745        10            윤희에게  2019-11-14     6   0.3%  12240000
#
#              누적매출액   관객수     누적관객수      점유율집계일  좌석판매점유율순위   좌석판매율  좌석점유율  \
# 9        162552500  1202     22070  2015-01-01          8   45.9%   0.1%
# ...

# %%
df_10['영화명'].unique()
# Out:
# array(['그 사람 그 사랑 그 세상', '다이빙벨', '워킹걸', '오늘의 연애', '목숨', '더 테너 리리코 스핀토',
#        '쿼바디스', '미라클 여행기', '생각보다 맑은', '조선명탐정 : 사라진 놉의 딸', '망원동 인공위성',
#        '허삼관', '어우동: 주인 없는 꽃', '님아, 그 강을 건너지 마오', '내 심장을 쏴라', '하숙집', '기화',
#        '친절한 가정부', '강남 1970', '살인의뢰', '꿈보다 해몽', '소셜포비아', '개: dog eat dog',
#        '쎄시봉', '최강전사 미니특공대 : 새로운 악당의 습격', '들개', '개를 훔치는 완벽한 방법', '스물',
#        '몽골리안 프린세스', '조류인간', '나는 야한 여자가 좋다 3', '장수상회', '미디어로 행동하라 in 삼척',
#        'SIDOF2015_비보이가 되다/ 굿바이 / 이 시대의 사랑',
#        'SIDOF2015_편지 / 감정의 시대: 서비스 노동의 관계미학 / 트라우마는 인간의 뇌에 어떠한 영향을 미치는가?',
#        '대답해줘', '60만번의 트라이', '태양을 쏴라', '국제시장', '순수의 시대', '화장', '약장수',
#        '헬머니', '그라운드의 이방인', '다이빙벨: 진실은 침몰하지 않습니다', '명량: 회오리 바다를 향하여',
#        '후쿠시마의 미래', '미궁: 비밀애', '연애의 맛', '검은손', '파울볼', '플랑크 상수', '부곡 하와이',
#        '반짝이는 박수 소리', '명령불복종 교사', '위험한 상견례 2', '잡식가족의 딜레마', '다이노 타임',
#        '막걸스', '마이 페어 웨딩', '코인라커', '성난 화가', '산다', '차이나타운', '경성학교: 사라진 소녀들',
#        '연평해전', '악의 연대기', '은밀한 유혹', '메이드 인 차이나', '애인', '카토 프로젝트',
# ...

# %%
df_1['영화명'].unique()
# Out:
# array(['국제시장', '강남 1970', '쎄시봉', '조선명탐정 : 사라진 놉의 딸', '순수의 시대', '살인의뢰',
#        '스물', '장수상회', '차이나타운', '악의 연대기', '간신', '무뢰한', '은밀한 유혹', '극비수사',
#        '연평해전', '암살', '베테랑', '사도', '성난 변호사', '특종: 량첸살인기', '더 폰', '그놈이다',
#        '검은 사제들', '내부자들', '히말라야', '내부자들: 디 오리지널', '그날의 분위기', '오빠생각',
#        '로봇, 소리', '검사외전', '귀향', '글로리데이', '대배우', '날, 보러와요', '시간이탈자',
#        '탐정 홍길동: 사라진 마을', '곡성', '아가씨', '특별수사: 사형수의 편지', '사냥', '굿바이 싱글',
#        '봉이 김선달', '부산행', '인천상륙작전', '덕혜옹주', '터널', '밀정', '아수라', '럭키', '스플릿',
#        '가려진 시간', '형', '판도라', '마스터', '더 킹', '공조', '조작된 도시', '재심', '해빙',
#        '비정규직 특수요원', '프리즌', '아빠는 딸', '특별시민', '보안관', '불한당: 나쁜 놈들의 세상',
#        '노무현입니다', '대립군', '악녀', '하루', '리얼', '박열', '군함도', '택시운전사', '브이아이피',
#        '청년경찰', '살인자의 기억법', '아이 캔 스피크', '남한산성', '범죄도시', '부라더', '7호실', '꾼',
#        '강철비', '신과함께-죄와 벌', '1987', '그것만이 내 세상', '염력', '조선명탐정: 흡혈괴마의 비밀',
#        '골든슬럼버', '궁합', '리틀 포레스트', '사라진 밤', '지금 만나러 갑니다', '7년의 밤', '곤지암',
# ...

# %%
jang=df[df['영화명']=='장사리 : 잊혀진 영웅들']

# %%
jang.head(-1)
# Out:
#                  영화명         개봉일       관객수      누적관객수           매출액  \
# 68108  장사리 : 잊혀진 영웅들  2019-09-25    1253.0     1253.0  1.127700e+07
# 68349  장사리 : 잊혀진 영웅들  2019-09-25  129938.0   138274.0  7.703675e+08
# 68406  장사리 : 잊혀진 영웅들  2019-09-25    3644.0     8336.0  3.321900e+07
# 68496  장사리 : 잊혀진 영웅들  2019-09-25     405.0     4692.0  3.083000e+06
# 68668  장사리 : 잊혀진 영웅들  2019-09-25    1808.0     4287.0  1.627200e+07
# 68715  장사리 : 잊혀진 영웅들  2019-09-25    1226.0     2479.0  1.103400e+07
# 68742  장사리 : 잊혀진 영웅들  2019-09-25   36501.0   860297.0  2.737594e+08
# 68782  장사리 : 잊혀진 영웅들  2019-09-25   64314.0   823796.0  4.864578e+08
# 68825  장사리 : 잊혀진 영웅들  2019-09-25   69775.0   759482.0  5.313062e+08
# 68865  장사리 : 잊혀진 영웅들  2019-09-25  191905.0   689707.0  1.634164e+09
# 68908  장사리 : 잊혀진 영웅들  2019-09-25  201935.0   497802.0  1.729930e+09
# 68952  장사리 : 잊혀진 영웅들  2019-09-25   91320.0   295867.0  7.690715e+08
# 68998  장사리 : 잊혀진 영웅들  2019-09-25   66273.0   204547.0  5.214220e+08
# ...

# %%
df_up.dtypes
# Out:
# 스크린점유율순위      int64
# 영화명          object
# 개봉일          object
# 스크린수          int64
# 스크린점유율       object
# 매출액           int64
# 누적매출액         int64
# 관객수           int64
# 누적관객수         int64
# 점유율집계일       object
# 좌석판매점유율순위     int64
# 좌석판매율        object
# 좌석점유율        object
# 좌석수           int64
# 순위            int64
# 상영횟수          int64
# 상영점유율        object
# dtype: object

# %%
df_up.head(1)
# Out:
#    스크린점유율순위   영화명         개봉일  스크린수 스크린점유율         매출액        누적매출액     관객수  \
# 0         1  국제시장  2014-12-17   941  35.8%  6129982500  47219550096  751754
#
#      누적관객수      점유율집계일  좌석판매점유율순위  좌석판매율   좌석점유율     좌석수  순위  상영횟수    상영점유율
# 0  6097431  2015-01-01          1  78.0%  34.99%  964153   1  4650  45.651%

# %%
forest=df[df['영화명'] == '리틀 포레스트']

# %%
forest.head()
# Out:
#            영화명         개봉일       관객수     누적관객수          매출액        누적매출액  \
# 45392  리틀 포레스트  2018-02-28    3239.0    3239.0   21524000.0   21524000.0
# 45626  리틀 포레스트  2018-02-28    2740.0   12825.0   21636000.0   89852700.0
# 45657  리틀 포레스트  2018-02-28    6846.0   10085.0   46692700.0   68216700.0
# 45835  리틀 포레스트  2018-02-28  131350.0  146948.0  779250900.0  889188600.0
# 45887  리틀 포레스트  2018-02-28    1354.0   15598.0   12106000.0  109937700.0
#
#        상영_순위    상영점유율    상영횟수   상영_점유율집계일  좌석_순위   좌석판매율   좌석점유율       좌석수  \
# 45392   14.0   0.138%    15.0  2018-02-13    9.0  100.0%   0.12%    3238.0
# 45626   13.0   0.148%    12.0  2018-02-21   13.0  100.0%    0.1%    2740.0
# 45657   10.0   0.462%    40.0  2018-02-20    8.0   80.8%   0.31%    8477.0
# 45835    1.0  43.516%  4188.0  2018-02-28    1.0   17.3%  25.29%  761215.0
# 45887   15.0   0.177%    10.0  2018-02-27   14.0   77.4%   0.06%    1750.0
#
#         좌석_점유율집계일  스크린_순위 스크린점유율   스크린수  스크린_점유율집계일
# ...

# %%
con=pd.concat([forest, jang])

# %%
con.head()
# Out:
#            영화명         개봉일       관객수     누적관객수          매출액        누적매출액  \
# 45392  리틀 포레스트  2018-02-28    3239.0    3239.0   21524000.0   21524000.0
# 45626  리틀 포레스트  2018-02-28    2740.0   12825.0   21636000.0   89852700.0
# 45657  리틀 포레스트  2018-02-28    6846.0   10085.0   46692700.0   68216700.0
# 45835  리틀 포레스트  2018-02-28  131350.0  146948.0  779250900.0  889188600.0
# 45887  리틀 포레스트  2018-02-28    1354.0   15598.0   12106000.0  109937700.0
#
#        상영_순위    상영점유율    상영횟수   상영_점유율집계일  좌석_순위   좌석판매율   좌석점유율       좌석수  \
# 45392   14.0   0.138%    15.0  2018-02-13    9.0  100.0%   0.12%    3238.0
# 45626   13.0   0.148%    12.0  2018-02-21   13.0  100.0%    0.1%    2740.0
# 45657   10.0   0.462%    40.0  2018-02-20    8.0   80.8%   0.31%    8477.0
# 45835    1.0  43.516%  4188.0  2018-02-28    1.0   17.3%  25.29%  761215.0
# 45887   15.0   0.177%    10.0  2018-02-27   14.0   77.4%   0.06%    1750.0
#
#         좌석_점유율집계일  스크린_순위 스크린점유율   스크린수  스크린_점유율집계일
# ...

# %%
ax = sns.lineplot(x='상영_점유율집계일', 

                  y='스크린수', 

                  hue='영화명',
                  palette= ['g', 'r'],
                  #figsize=(20,8),
                  linewidth = 2,
                  data=con)

#plt.yticks([0,1,2])
#plt.xticks([1997, 1999, 2001, 2003, 2005, 2007, 2009, 2011, 2013, 2015, 2017, 2019])

plt.title('리틀포레스트-장사리 스크린수 비교', fontsize=15)

plt.ylabel('작품수', fontsize=14)

plt.xlabel('년도', fontsize=14)

#plt.legend(fontsize=10, loc='best')

# 범례 위치 조절
plt.legend(loc='upper center', bbox_to_anchor=(1.2, 0.8), shadow=True)

plt.show()

# %% [markdown]
# # 1919 유관순과 장사리 비교
# - 두 영화 집계일 비슷.
# - 유관순에 개봉일 없어서 넣어야할 듯.

# %%
fd = df_up[(df_up['점유율집계일']>= '2019-09-01') & (df_up['점유율집계일']<='2019-11-07')]

# %%
fd[:-10 ]
# Out:
#        스크린점유율순위                   영화명         개봉일  스크린수 스크린점유율         매출액  \
# 55802         1              유열의 음악앨범  2019-08-28  1032  23.9%  1276019900
# 55803         2                    변신  2019-08-21   888  20.5%  1132455850
# 55804         3                   엑시트  2019-07-31   800  18.5%   905597200
# 55805         4                봉오동 전투  2019-08-07   499  11.5%   249028200
# 55806         5            광대들: 풍문조작단  2019-08-21   462  10.7%   162152810
# ...         ...                   ...         ...   ...    ...         ...
# 58799        22                   이어도         NaN     1   0.1%           0
# 58800        22        1919유관순-그녀들의조국         NaN     1   0.1%        2000
# 58801        22          아직 지나지 않은 여름  2019-11-01     1   0.1%        6000
# 58802        22  극장판 헬로카봇 : 달나라를 구해줘!  2019-09-04     1   0.1%       90000
# 58803        22          나쁜 녀석들: 더 무비  2019-09-11     1   0.1%        6000
#
# ...

# %%
her=df[df['영화명'] == '1919유관순-그녀들의조국']

# %%
her.head()
# Out:
#                   영화명  개봉일  관객수  누적관객수     매출액    누적매출액  상영_순위   상영점유율  상영횟수  \
# 69837  1919유관순-그녀들의조국  NaN  1.0    2.0  2000.0   4000.0   41.0   0.01%   1.0
# 69879  1919유관순-그녀들의조국  NaN  1.0    1.0  2000.0   2000.0   41.0  0.014%   1.0
# 69936  1919유관순-그녀들의조국  NaN  0.0    0.0     0.0      0.0   41.0  0.014%   1.0
# 70226  1919유관순-그녀들의조국  NaN  1.0    5.0  2000.0  10000.0   32.0  0.017%   1.0
# 70459  1919유관순-그녀들의조국  NaN  1.0    4.0  2000.0   8000.0   35.0   0.01%   1.0
#
#         상영_점유율집계일  좌석_순위 좌석판매율  좌석점유율    좌석수   좌석_점유율집계일  스크린_순위 스크린점유율  스크린수  \
# 69837  2019-10-23   32.0  0.4%  0.01%  260.0  2019-10-17    36.0   0.0%   1.0
# 69879  2019-10-22   33.0  0.4%  0.01%  260.0  2019-10-18    37.0   0.0%   1.0
# 69936  2019-10-21   33.0  0.0%  0.01%  260.0  2019-10-19    37.0   0.0%   1.0
# 70226  2019-10-30   21.0  0.4%  0.01%  260.0  2019-10-24    25.0   0.1%   1.0
# 70459  2019-10-25   31.0  0.4%  0.01%  260.0  2019-10-29    34.0   0.0%   1.0
#
#        스크린_점유율집계일
# ...

# %%
her.head()
# Out:
#                   영화명  개봉일  관객수  누적관객수     매출액    누적매출액  상영_순위   상영점유율  상영횟수  \
# 69837  1919유관순-그녀들의조국  NaN  1.0    2.0  2000.0   4000.0   41.0   0.01%   1.0
# 69879  1919유관순-그녀들의조국  NaN  1.0    1.0  2000.0   2000.0   41.0  0.014%   1.0
# 69936  1919유관순-그녀들의조국  NaN  0.0    0.0     0.0      0.0   41.0  0.014%   1.0
# 70226  1919유관순-그녀들의조국  NaN  1.0    5.0  2000.0  10000.0   32.0  0.017%   1.0
# 70459  1919유관순-그녀들의조국  NaN  1.0    4.0  2000.0   8000.0   35.0   0.01%   1.0
#
#         상영_점유율집계일  좌석_순위 좌석판매율  좌석점유율    좌석수   좌석_점유율집계일  스크린_순위 스크린점유율  스크린수  \
# 69837  2019-10-23   32.0  0.4%  0.01%  260.0  2019-10-17    36.0   0.0%   1.0
# 69879  2019-10-22   33.0  0.4%  0.01%  260.0  2019-10-18    37.0   0.0%   1.0
# 69936  2019-10-21   33.0  0.0%  0.01%  260.0  2019-10-19    37.0   0.0%   1.0
# 70226  2019-10-30   21.0  0.4%  0.01%  260.0  2019-10-24    25.0   0.1%   1.0
# 70459  2019-10-25   31.0  0.4%  0.01%  260.0  2019-10-29    34.0   0.0%   1.0
#
#        스크린_점유율집계일
# ...

# %%
her_=pd.concat([her, jang])

# %%
her_
# Out:
#                   영화명         개봉일       관객수      누적관객수           매출액  \
# 69837  1919유관순-그녀들의조국         NaN       1.0        2.0  2.000000e+03
# 69879  1919유관순-그녀들의조국         NaN       1.0        1.0  2.000000e+03
# 69936  1919유관순-그녀들의조국         NaN       0.0        0.0  0.000000e+00
# 70226  1919유관순-그녀들의조국         NaN       1.0        5.0  2.000000e+03
# 70459  1919유관순-그녀들의조국         NaN       1.0        4.0  2.000000e+03
# 70513  1919유관순-그녀들의조국         NaN       1.0        3.0  2.000000e+03
# 70557  1919유관순-그녀들의조국         NaN       1.0       26.0  2.000000e+03
# 70843  1919유관순-그녀들의조국         NaN      20.0       25.0  4.000000e+04
# 68108   장사리 : 잊혀진 영웅들  2019-09-25    1253.0     1253.0  1.127700e+07
# 68349   장사리 : 잊혀진 영웅들  2019-09-25  129938.0   138274.0  7.703675e+08
# 68406   장사리 : 잊혀진 영웅들  2019-09-25    3644.0     8336.0  3.321900e+07
# 68496   장사리 : 잊혀진 영웅들  2019-09-25     405.0     4692.0  3.083000e+06
# 68668   장사리 : 잊혀진 영웅들  2019-09-25    1808.0     4287.0  1.627200e+07
# ...

# %%
ax = sns.lineplot(x='상영_점유율집계일', 

                  y='스크린수', 

                  hue='영화명',
                  palette= ['g', 'r'],
                  #figsize=(20,8),
                  linewidth = 2,
                  data=her_)

#plt.yticks([0,1,2])
#plt.xticks([1997, 1999, 2001, 2003, 2005, 2007, 2009, 2011, 2013, 2015, 2017, 2019])

plt.title('1919유관순 - 장사리 스크린수 비교', fontsize=15)

plt.ylabel('스크린수', fontsize=14)

plt.xlabel('년도', fontsize=14)

#plt.legend(fontsize=10, loc='best')

# 범례 위치 조절
plt.legend(loc='upper center', bbox_to_anchor=(1.5, 0.8), shadow=True)

plt.show()

# %%
ax = sns.lineplot(x='상영_점유율집계일', 

                  y='스크린수', 

                  hue='영화명',
                  palette= ['r'],
                  #figsize=(20,8),
                  linewidth = 2,
                  data=jang)

#plt.yticks([0,1,2])
#plt.xticks([1997, 1999, 2001, 2003, 2005, 2007, 2009, 2011, 2013, 2015, 2017, 2019])

plt.title('장사리 스크린수 비교', fontsize=15)

plt.ylabel('스크린수', fontsize=14)

plt.xlabel('년도', fontsize=14)

#plt.legend(fontsize=10, loc='best')

# 범례 위치 조절
plt.legend(loc='upper center', bbox_to_anchor=(1.5, 0.8), shadow=True)

plt.show()

# %%
ax = sns.lineplot(x='상영_점유율집계일', 

                  y='스크린수', 

                  hue='영화명',
                  palette= ['g'],
                  #figsize=(20,8),
                  linewidth = 2,
                  data=her)

plt.title('1919유관순 스크린수 비교', fontsize=15)

plt.ylabel('스크린수', fontsize=14)

plt.xlabel('년도', fontsize=14)

# 범례 위치 조절
plt.legend(loc='upper center', bbox_to_anchor=(1.5, 0.8), shadow=True)

plt.show()

# %%
jang['영화명'].unique()
# Out:
# array(['장사리 : 잊혀진 영웅들'], dtype=object)

# %% [markdown]
# 장사리와 1919 유관순의 그래프를 같이 그릴 때는, 장사리의 x축 그래프가 뭔가 이상한데 따로 그렸을 경우 이상함을 느낄 수 없다...
#
# 따로 그린 후 알게 된 사실은 1919유관순은 최대/최소 스크린수가 1이라는 점이다...

# %% [markdown]
# # 개봉일 비워져있는 영화 채우기
# 다른 데이터를 찍을 때는 이상한데 df_up을 찍으면 이상함이 없다..그냥 다른 작업을 하자.

# %%
df_up.isnull().sum()
# Out:
# 스크린점유율순위        0
# 영화명             0
# 개봉일          5515
# 스크린수            0
# 스크린점유율          0
# 매출액             0
# 누적매출액           0
# 관객수             0
# 누적관객수           0
# 점유율집계일          0
# 좌석판매점유율순위       0
# 좌석판매율           0
# 좌석점유율           0
# 좌석수             0
# 순위              0
# 상영횟수            0
# 상영점유율           0
# dtype: int64

# %%
df_up[df_up['영화명']=='1919 유관순']
# Out:
#        스크린점유율순위       영화명         개봉일  스크린수 스크린점유율       매출액      누적매출액   관객수  \
# 49493        17  1919 유관순  2019-03-14     1   0.0%   1950000    1950000   195
# 49561        11  1919 유관순  2019-03-14     7   0.3%  12971000   14921000  1465
# 49595        13  1919 유관순  2019-03-14     5   0.2%   6885000   21806000   765
# 49626         9  1919 유관순  2019-03-14     5   0.2%   4527000   26333000   503
# 49654         5  1919 유관순  2019-03-14   269  14.5%  23149770   49482770  3017
# ...         ...       ...         ...   ...    ...       ...        ...   ...
# 57661        39  1919 유관순  2019-03-14     1   0.0%         0  506367410     0
# 57718        38  1919 유관순  2019-03-14     1   0.0%         0  506367410     0
# 57770        35  1919 유관순  2019-03-14     1   0.0%         0  506367410     0
# 57813        37  1919 유관순  2019-03-14     1   0.0%         0  506367410     0
# 57885        34  1919 유관순  2019-03-14     1   0.0%         0  506367410     0
#
# ...

# %%
df_up[df_up['개봉일'].isnull()]
# Out:
#        스크린점유율순위                 영화명  개봉일  스크린수 스크린점유율       매출액       누적매출액  \
# 6             7  뽀로로 극장판 눈요정 마을 대모험  NaN    66   2.5%  27846600  1188395900
# 13           13            민우씨 오는 날  NaN     3   0.1%     87000     3415500
# 32            7  뽀로로 극장판 눈요정 마을 대모험  NaN    50   1.9%  15771200  1204167100
# 40           12            민우씨 오는 날  NaN     3   0.1%     89000     3504500
# 55            7  뽀로로 극장판 눈요정 마을 대모험  NaN    66   2.4%  21371300  1225538400
# ...         ...                 ...  ...   ...    ...       ...         ...
# 58767        21           아 백범 김구선생  NaN     1   0.1%      2000     3460000
# 58799        22                 이어도  NaN     1   0.1%         0     3763500
# 58800        22      1919유관순-그녀들의조국  NaN     1   0.1%      2000       52000
# 58810        22              빨간 마후라  NaN     1   0.1%    204000    17325000
# 58811        22           아 백범 김구선생  NaN     1   0.1%     22000     3482000
#
# ...

# %%
her.head(3)
# Out:
#                   영화명  개봉일  관객수  누적관객수     매출액   누적매출액  상영_순위   상영점유율  상영횟수  \
# 69837  1919유관순-그녀들의조국  NaN  1.0    2.0  2000.0  4000.0   41.0   0.01%   1.0
# 69879  1919유관순-그녀들의조국  NaN  1.0    1.0  2000.0  2000.0   41.0  0.014%   1.0
# 69936  1919유관순-그녀들의조국  NaN  0.0    0.0     0.0     0.0   41.0  0.014%   1.0
#
#         상영_점유율집계일  좌석_순위 좌석판매율  좌석점유율    좌석수   좌석_점유율집계일  스크린_순위 스크린점유율  스크린수  \
# 69837  2019-10-23   32.0  0.4%  0.01%  260.0  2019-10-17    36.0   0.0%   1.0
# 69879  2019-10-22   33.0  0.4%  0.01%  260.0  2019-10-18    37.0   0.0%   1.0
# 69936  2019-10-21   33.0  0.0%  0.01%  260.0  2019-10-19    37.0   0.0%   1.0
#
#        스크린_점유율집계일
# 69837  2019-10-17
# 69879  2019-10-18
# 69936  2019-10-19

# %% [markdown]
# 개봉일 비워져있는 것이 왜 없나 싶었더니.....NaN으로 채워져 있음. NaN을 검색해도 안나옴.

# %%
df_up[df_up['개봉일']==np.nan]
# Out:
# Empty DataFrame
# Columns: [스크린점유율순위, 영화명, 개봉일, 스크린수, 스크린점유율, 매출액, 누적매출액, 관객수, 누적관객수, 점유율집계일, 좌석판매점유율순위, 좌석판매율, 좌석점유율, 좌석수, 순위, 상영횟수, 상영점유율]
# Index: []

# %%
df_up.isnull().any()
# Out:
# 스크린점유율순위     False
# 영화명          False
# 개봉일           True
# 스크린수         False
# 스크린점유율       False
# 매출액          False
# 누적매출액        False
# 관객수          False
# 누적관객수        False
# 점유율집계일       False
# 좌석판매점유율순위    False
# 좌석판매율        False
# 좌석점유율        False
# 좌석수          False
# 순위           False
# 상영횟수         False
# 상영점유율        False
# dtype: bool

# %%
df_up.dtypes
# Out:
# 스크린점유율순위      int64
# 영화명          object
# 개봉일          object
# 스크린수          int64
# 스크린점유율       object
# 매출액           int64
# 누적매출액         int64
# 관객수           int64
# 누적관객수         int64
# 점유율집계일       object
# 좌석판매점유율순위     int64
# 좌석판매율        object
# 좌석점유율        object
# 좌석수           int64
# 순위            int64
# 상영횟수          int64
# 상영점유율        object
# dtype: object

# %%
df_up.astype({'개봉일':str}).dtypes
# Out:
# 스크린점유율순위      int64
# 영화명          object
# 개봉일          object
# 스크린수          int64
# 스크린점유율       object
# 매출액           int64
# 누적매출액         int64
# 관객수           int64
# 누적관객수         int64
# 점유율집계일       object
# 좌석판매점유율순위     int64
# 좌석판매율        object
# 좌석점유율        object
# 좌석수           int64
# 순위            int64
# 상영횟수          int64
# 상영점유율        object
# dtype: object

# %% [markdown]
# 자세히 보니 결측치가 없다. 다른 것을 하자.

# %% [markdown]
# # 다른 작업 시작

# %%
df_up.dtypes
# Out:
# 스크린점유율순위      int64
# 영화명          object
# 개봉일          object
# 스크린수          int64
# 스크린점유율       object
# 매출액           int64
# 누적매출액         int64
# 관객수           int64
# 누적관객수         int64
# 점유율집계일       object
# 좌석판매점유율순위     int64
# 좌석판매율        object
# 좌석점유율        object
# 좌석수           int64
# 순위            int64
# 상영횟수          int64
# 상영점유율        object
# dtype: object

# %%
df_up.head()
# Out:
#   스크린점유율순위              영화명         개봉일 스크린수 스크린점유율         매출액        누적매출액  \
# 0        1             국제시장  2014-12-17  941  35.8%  6129982500  47219550096
# 1        2  님아, 그 강을 건너지 마오  2014-11-27  473  18.0%  1479015600  31324845079
# 2        3             기술자들  2014-12-24  464  17.7%  1299883700  14952363848
# 3        4              상의원  2014-12-24  258   9.8%   230484800   5524209364
# 4        5    개를 훔치는 완벽한 방법  2014-12-31  196   7.5%   299346400    608002300
#
#       관객수    누적관객수      점유율집계일 좌석판매점유율순위  좌석판매율   좌석점유율     좌석수 순위  상영횟수  \
# 0  751754  6097431  2015-01-01         1  78.0%  34.99%  964153  1  4650
# 1  178941  4025319  2015-01-01         3  67.2%   9.66%  266197  2  1979
# 2  160371  1938454  2015-01-01         2  57.9%  10.05%  276896  3  1886
# 3   28439   705071  2015-01-01         5  46.6%   2.22%   61095  5   491
# 4   37741    80633  2015-01-01         4  48.1%   2.85%   78410  4   650
#
#      상영점유율
# 0  45.651%
# 1  19.429%
# 2  18.516%
# 3    4.82%
# ...

# %%
back=df[df['영화명'] == '미쓰백']

# %%
back.head(2)
# Out:
#        영화명         개봉일    관객수   누적관객수        매출액      누적매출액  상영_순위   상영점유율  \
# 53296  미쓰백  2018-10-11  786.0   786.0  5764000.0  5764000.0   19.0  0.039%
# 53774  미쓰백  2018-10-11  247.0  1033.0  1482000.0  7246000.0   27.0   0.01%
#
#        상영횟수   상영_점유율집계일  좌석_순위   좌석판매율  좌석점유율    좌석수   좌석_점유율집계일  스크린_순위  \
# 53296   3.0  2018-09-11   16.0  100.0%  0.03%  786.0  2018-09-07    19.0
# 53774   1.0  2018-09-13   24.0  100.0%  0.01%  247.0  2018-09-19    26.0
#
#       스크린점유율  스크린수  스크린_점유율집계일
# 53296   0.0%   1.0  2018-09-07
# 53774   0.0%   1.0  2018-09-19

# %%
ax = sns.lineplot(x='스크린_점유율집계일', 

                  y='스크린수', 

                  hue='영화명',
                  palette= ['g'],
                  #figsize=(20,8),
                  linewidth = 2,
                  data=back)

#plt.yticks([0,1,2])
#plt.xticks([1997, 1999, 2001, 2003, 2005, 2007, 2009, 2011, 2013, 2015, 2017, 2019])

plt.title('미쓰백 스크린수 비교', fontsize=15)

plt.ylabel('스크린수', fontsize=14)

plt.xlabel('년도', fontsize=14)

#plt.legend(fontsize=10, loc='best')

# 범례 위치 조절
plt.legend(loc='upper center', bbox_to_anchor=(1.5, 0.8), shadow=True)

plt.show()

# %%
girl=df[df['영화명'] == '걸캅스']

# %%
ax = sns.lineplot(x='스크린_점유율집계일', 

                  y='스크린수', 

                  hue='영화명',
                  palette= ['g'],
                  #figsize=(20,8),
                  linewidth = 2,
                  data=girl)

#plt.yticks([0,1,2])
#plt.xticks([1997, 1999, 2001, 2003, 2005, 2007, 2009, 2011, 2013, 2015, 2017, 2019])

plt.title('걸캅스 스크린수 비교', fontsize=15)

plt.ylabel('스크린수', fontsize=14)

plt.xlabel('년도', fontsize=14)

#plt.legend(fontsize=10, loc='best')

# 범례 위치 조절
plt.legend(loc='upper center', bbox_to_anchor=(1.5, 0.8), shadow=True)

plt.show()

# %%
ican=df[df['영화명'] == '아이 캔 스피크']

# %%
ican.head()
# Out:
#             영화명         개봉일     관객수    누적관객수         매출액        누적매출액  상영_순위  \
# 38345  아이 캔 스피크  2017-09-21  7414.0   7414.0  61048000.0   61048000.0   11.0
# 38751  아이 캔 스피크  2017-09-21  1811.0  15156.0  14488000.0  127908000.0   16.0
# 38789  아이 캔 스피크  2017-09-21  1056.0  13345.0   8448000.0  113420000.0   14.0
# 38826  아이 캔 스피크  2017-09-21  2350.0  12289.0  18800000.0  104972000.0   13.0
# 38897  아이 캔 스피크  2017-09-21  2525.0   9939.0  25124000.0   86172000.0   13.0
#
#         상영점유율  상영횟수   상영_점유율집계일  좌석_순위   좌석판매율  좌석점유율     좌석수   좌석_점유율집계일  \
# 38345  0.349%  32.0  2017-09-06   11.0   99.3%  0.27%  7470.0  2017-08-31
# 38751  0.116%  10.0  2017-09-13   14.0   73.9%  0.09%  2452.0  2017-09-07
# 38789  0.066%   6.0  2017-09-12   14.0  100.4%  0.04%  1052.0  2017-09-08
# 38826   0.14%  13.0  2017-09-11   12.0  100.0%  0.09%  2350.0  2017-09-09
# 38897  0.101%  10.0  2017-09-09   13.0  100.0%  0.08%  2525.0  2017-09-11
#
#        스크린_순위 스크린점유율  스크린수  스크린_점유율집계일
# ...

# %%
ax = sns.lineplot(x='스크린_점유율집계일', 

                  y='스크린수', 

                  hue='영화명',
                  palette= ['g'],
                  #figsize=(20,8),
                  linewidth = 2,
                  data=ican)

#plt.yticks([0,1,2])
#plt.xticks([1997, 1999, 2001, 2003, 2005, 2007, 2009, 2011, 2013, 2015, 2017, 2019])

plt.title('아이캔스피크 스크린수 비교', fontsize=15)

plt.ylabel('스크린수', fontsize=14)

plt.xlabel('년도', fontsize=14)

#plt.legend(fontsize=10, loc='best')

# 범례 위치 조절
plt.legend(loc='upper center', bbox_to_anchor=(1.5, 0.8), shadow=True)

plt.show()

# %%
power=df[df['영화명'] == '염력']

# %%
ax = sns.lineplot(x='스크린_점유율집계일', 

                  y='스크린수', 

                  hue='영화명',
                  palette= ['r'],
                  #figsize=(20,8),
                  linewidth = 2,
                  data=power)

plt.title('염력 스크린수 비교', fontsize=15)

plt.ylabel('스크린수', fontsize=14)

plt.xlabel('년도', fontsize=14)

#plt.legend(fontsize=10, loc='best')

# 범례 위치 조절
plt.legend(loc='upper center', bbox_to_anchor=(1.5, 0.8), shadow=True)

plt.show()

# %%
ubd=df[df['영화명'] == '자전차왕 엄복동']

# %%
ubd.head()
# Out:
#             영화명         개봉일      관객수    누적관객수          매출액        누적매출액  \
# 60298  자전차왕 엄복동  2019-02-27    240.0    240.0    2640000.0    2640000.0
# 60372  자전차왕 엄복동  2019-02-27   1111.0   1351.0    9999000.0   12639000.0
# 60533  자전차왕 엄복동  2019-02-27  43408.0  51124.0  259362050.0  321850050.0
# 60571  자전차왕 엄복동  2019-02-27   2652.0   7716.0   19574000.0   62488000.0
# 60598  자전차왕 엄복동  2019-02-27   3145.0   5064.0   26299000.0   42914000.0
#
#        상영_순위    상영점유율    상영횟수   상영_점유율집계일  좌석_순위   좌석판매율   좌석점유율       좌석수  \
# 60298   17.0   0.024%     3.0  2019-02-08   17.0   83.3%   0.01%     288.0
# 60372   10.0   0.044%     5.0  2019-02-19   10.0   74.9%   0.05%    1483.0
# 60533    5.0  14.204%  2278.0  2019-02-27    5.0   13.5%  10.79%  321226.0
# 60571    9.0   0.069%     9.0  2019-02-26    6.0  100.0%   0.09%    2652.0
# 60598    8.0   0.138%    18.0  2019-02-25    6.0  100.0%   0.11%    3145.0
#
#         좌석_점유율집계일  스크린_순위 스크린점유율   스크린수  스크린_점유율집계일
# ...

# %%
ax = sns.lineplot(x='스크린_점유율집계일', 

                  y='스크린수', 

                  hue='영화명',
                  palette= ['r'],
                  #figsize=(20,8),
                  linewidth = 2,
                  data=ubd)

plt.title('자전차왕 엄복동 스크린수 비교', fontsize=15)

plt.ylabel('스크린수', fontsize=14)

plt.xlabel('년도', fontsize=14)

#plt.legend(fontsize=10, loc='best')

# 범례 위치 조절
plt.legend(loc='upper center', bbox_to_anchor=(1.5, 0.8), shadow=True)

plt.show()

# %%
bird=df[df['영화명'] == '벌새']

# %%
ax = sns.lineplot(x='스크린_점유율집계일', 

                  y='스크린수', 

                  hue='영화명',
                  palette= ['g'],
                  #figsize=(20,8),
                  linewidth = 2,
                  data=bird)

plt.title('벌새 스크린수 비교', fontsize=15)

plt.ylabel('스크린수', fontsize=14)

plt.xlabel('년도', fontsize=14)

#plt.legend(fontsize=10, loc='best')

# 범례 위치 조절
plt.legend(loc='upper center', bbox_to_anchor=(1.5, 0.8), shadow=True)

plt.show()

# %% [markdown]
# 좋은 영화: 미쓰백, 벌새, 허스토리, 우리들, 우리집, 아이캔스피크, 미성년, 소공녀, 걸캅스,
# F0: 극한직업, 리얼, VIP, 염력, 사자,
# -베테랑 한번 보면 나쁘지 않을 듯....
