# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

pd.set_option('display.max_columns', None)
# %matplotlib inline
plt.rcParams['font.family'] = 'NanumGothic'
warnings.filterwarnings('ignore')

# %%
films = pd.read_csv('../01.Data_Collection/films.csv')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_row', None)

# %%
films.head()
# Out:
#     순위       영화명        개봉일             매출액 매출액점유율           누적매출액        관객수  \
# 0   55       워킹걸   2015.1.7   1,183,887,479   0.1%   1,201,963,479    149,181
# 1  121        설해   2015.1.8      20,767,500   0.0%      29,770,500      2,796
# 2   26       허삼관  2015.1.14   7,408,943,569   0.8%   7,408,943,569    955,679
# 3   16    오늘의 연애  2015.1.14  14,924,654,487   1.7%  14,924,654,487  1,891,993
# 4  149  꽃보다 처녀귀신  2015.1.15       7,909,000   0.0%       7,909,000      1,567
#
#        누적관객수 스크린수    상영횟수 대표국적  국적                제작사  \
# 0    151,550  308   7,076   한국  한국      (주)홍필름,(주)수필름
# 1      3,933   34     335   한국  한국           (주)맑음영화사
# 2    955,679  621  27,645   한국  한국  (주)두타연,(주)판타지오픽쳐스
# 3  1,891,993  709  47,237   한국  한국          (주)팝콘에프앤엠
# 4      1,567    5      42   한국  한국        고구마콘텐츠허브(주)
#
#                          배급사        등급          장르   감독  \
# 0              메가박스중앙(주)플러스엠   청소년관람불가  코미디,멜로/로맨스  정범식
# ...

# %%
films.isnull().sum()
# Out:
# 순위          0
# 영화명         0
# 개봉일         0
# 매출액         0
# 매출액점유율      0
# 누적매출액       0
# 관객수         0
# 누적관객수       0
# 스크린수        0
# 상영횟수        0
# 대표국적        0
# 국적          0
# 제작사        20
# 배급사         1
# 등급          0
# 장르          0
# 감독          3
# 배우         31
# 배역명       449
# 영화코드        0
# 배우코드       28
# 주연배우       23
# 역할         28
# 배우성별       23
# dtype: int64

# %% [markdown]
# # 제작사 넣기

# %%
films[films['제작사'].isnull()]
# Out:
#       순위          영화명         개봉일          매출액 매출액점유율        누적매출액     관객수  \
# 252  415       미스터 쿠퍼   2016.6.30    1,124,000   0.0%    1,124,000     220
# 336   98           문영   2017.1.12   57,651,900   0.0%   60,471,599   7,530
# 394  119       델타 보이즈    2017.6.8   28,002,600   0.0%   30,466,900   3,894
# 406  151     노후 대책 없다   2017.6.29   10,756,500   0.0%   11,753,000   1,607
# 450  194          그리다  2017.10.26    5,996,300   0.0%    5,996,300     861
# 500   91       피의 연대기   2018.1.18   82,887,200   0.0%   83,680,200  10,631
# 575  112      튼튼이의 모험   2018.6.21   34,828,600   0.0%   35,593,600   4,701
# 617  133      나부야 나부야   2018.9.20   15,062,400   0.0%   15,062,400   2,789
# 628  131       집의 시간들  2018.10.25   24,033,950   0.0%   24,136,450   2,873
# 640  160         마담 B  2018.11.15    9,808,200   0.0%    9,907,200   1,461
# 645   79           영주  2018.11.22  191,696,250   0.0%  191,696,250  24,676
# ...

# %%
# 제작사 찾아서 넣음. 제작사 정보가 없는 영화는 '-' 로 표시함. 
films.iloc[252, 12] = '-'
films.iloc[336, 12] = '-'
films.iloc[394, 12] = '-'
films.iloc[406, 12] = '-'
films.iloc[450, 12] = '-'
films.iloc[500, 12] = '-'
films.iloc[575, 12] = '-'
films.iloc[617, 12] = '-'
films.iloc[628, 12] = '-'
films.iloc[640, 12] = '-'
films.iloc[645, 12] = 'KARTS 영주프로덕션'
films.iloc[660, 12] = '-'
films.iloc[689, 12] = '-'
films.iloc[690, 12] = '-'
films.iloc[691, 12] = '전태일 47주기 대구시민 노동문화제 , 독립영화전용관 오오극장 , 민예총 대구지회'
films.iloc[706, 12] = '영화사 책방'
films.iloc[731, 12] = '-'
films.iloc[740, 12] = '-'
films.iloc[759, 12] = '-'
films.iloc[794, 12] = '시소'

# %%
films[films['제작사'].isnull()]
# Out:
# Empty DataFrame
# Columns: [순위, 영화명, 개봉일, 매출액, 매출액점유율, 누적매출액, 관객수, 누적관객수, 스크린수, 상영횟수, 대표국적, 국적, 제작사, 배급사, 등급, 장르, 감독, 배우, 배역명, 영화코드, 배우코드, 주연배우, 역할, 배우성별]
# Index: []

# %% [markdown]
# # 배급사 넣기

# %%
films[films['배급사'].isnull()]
# Out:
# Empty DataFrame
# Columns: [순위, 영화명, 개봉일, 매출액, 매출액점유율, 누적매출액, 관객수, 누적관객수, 스크린수, 상영횟수, 대표국적, 국적, 제작사, 배급사, 등급, 장르, 감독, 배우, 배역명, 영화코드, 배우코드, 주연배우, 역할, 배우성별]
# Index: []

# %%
films.iloc[638, 13] = '-'

# %% [markdown]
# # 감독 넣기

# %%
films[films['감독'].isnull()]
# Out:
# Empty DataFrame
# Columns: [순위, 영화명, 개봉일, 매출액, 매출액점유율, 누적매출액, 관객수, 누적관객수, 스크린수, 상영횟수, 대표국적, 국적, 제작사, 배급사, 등급, 장르, 감독, 배우, 배역명, 영화코드, 배우코드, 주연배우, 역할, 배우성별]
# Index: []

# %%
# 감독 정보가 없어서 '-' 넣음. / 가수 다큐 영화
films.iloc[499, 16] = '-'
films.iloc[658, 16] = '-'
films.iloc[676, 16] = '-'

# %% [markdown]
# # 배우 넣기

# %%
films[films['배우'].isnull()]
# Out:
# Empty DataFrame
# Columns: [순위, 영화명, 개봉일, 매출액, 매출액점유율, 누적매출액, 관객수, 누적관객수, 스크린수, 상영횟수, 대표국적, 국적, 제작사, 배급사, 등급, 장르, 감독, 배우, 배역명, 영화코드, 배우코드, 주연배우, 역할, 배우성별]
# Index: []

# %%
# 영화 배우 이름 찾아서 넣음. 배우 정보가 없는 영화는 '-' 로 표시함. 

films.iloc[34, 17] = '이종인'
films.iloc[44, 17] = '황윤'
films.iloc[74, 17] = '김말해, 박은순, 손희경, 김영자'
films.iloc[82, 17] = '강타, 보아, 동방신기, 소녀시대, 샤이니, 에프엑스, 레드벨벳'
films.iloc[116, 17] = '-'
films.iloc[125, 17] = '도꾜 조선 중고급학교 권투부, 김상수'
films.iloc[150, 17] = '윤기진, 황선, 윤민, 윤겨레'
films.iloc[161, 17] = '권기선, 이준교'
films.iloc[168, 17] = '-'
films.iloc[172, 17] = '문남숙, 정혜옥, 최하나, 김영선, 전숙경, 김은아, 엄상현, 신용우'
films.iloc[233, 17] = '이종락'
films.iloc[243, 17] = '엘리자 구티, 아니카 쾀보카'
films.iloc[257, 17] = '엄상현, 이선호, 미야케켄타, 코지로치에, 아스미카나'
films.iloc[269, 17] = '김진숙, 박성호, 박희찬, 윤국성, 정태훈, 김지연, 정이균'
films.iloc[279, 17] = '상현, 정선, 복수, 진태'
films.iloc[292, 17] = '아케사카 사토미, 아스미 카나, 치바 스스무, 고토 사오리, 하라 사유리, 이토 카나에, 카키하라 테츠야, 카토 에미리'
films.iloc[302, 17] = '고찬근, 오은규, 황건, 트리오 오원, 채재일'
films.iloc[306, 17] = '소 알로이시오'
films.iloc[393, 17] = '-'
films.iloc[401, 17] = '배미영, 이수미, 김정숙, 이희동, 배정하, 이국민, 배은하'
films.iloc[412, 17] = '-'
films.iloc[413, 17] = '이묵, 논, 텐, 이영'
films.iloc[441, 17] = '파드마 앙뚜, 우르갼 릭젠'
films.iloc[455, 17] = '안젤로 델 베키오, 히바 티와지, 리챠드 샤레스, 다니엘 라부아, 마틴자루, 알리제 라랑드, 제이'
films.iloc[486, 17] = '종호, 이자은, 김하림, 백마리, 강주리'
films.iloc[509, 17] = '배정미, 김선혜, 서지연, 사성웅, 전태열, 안용욱'
films.iloc[596, 17] = '-'
films.iloc[640, 17] = '-'
films.iloc[719, 17] = '김종훈, 최국인, 지나이다 이바노브나, 한 아드레이, 한지마, 문 빅토르, 좌바예프 무싸베코프'
films.iloc[756, 17] = '-'
films.iloc[777, 17] = '김내현, 김진규, 이민우, 최민규, 안지, 김영진, 백선혁, 정유겸'

# %%
films[films['배우'].isnull()]
# Out:
# Empty DataFrame
# Columns: [순위, 영화명, 개봉일, 매출액, 매출액점유율, 누적매출액, 관객수, 누적관객수, 스크린수, 상영횟수, 대표국적, 국적, 제작사, 배급사, 등급, 장르, 감독, 배우, 배역명, 영화코드, 배우코드, 주연배우, 역할, 배우성별]
# Index: []

# %% [markdown]
# # 배역명 넣기

# %%
films.sample()
# Out:
#     순위      영화명       개봉일         매출액 매출액점유율       누적매출액    관객수  누적관객수 스크린수  \
# 91  93  기적의 피아노  2015.9.3  63,003,800   0.0%  63,003,800  8,567  8,567   74
#
#    상영횟수 대표국적  국적         제작사            배급사     등급     장르       감독  \
# 91  958   한국  한국  (주)보고싶은영화사  롯데쇼핑㈜롯데엔터테인먼트  전체관람가  다큐멘터리  임성구,김은주
#
#                                  배우  배역명      영화코드        배우코드 주연배우  역할 배우성별
# 91  유예은,박정순,유장주,박유천,정혜연,정옥화,김현지,김현희  유예은  20153311  20214266.0  유예은  배우   여자

# %%
films[films['배역명'].isnull()]
# Out:
#       순위                           영화명         개봉일              매출액 매출액점유율  \
# 19   151                개: dog eat dog    2015.3.5       11,970,000   0.0%
# 21    34                           헬머니    2015.3.5    4,120,166,972   0.5%
# 24   276                     몽골리안 프린세스   2015.3.19        3,254,000   0.0%
# 25   109                     그라운드의 이방인   2015.3.19       26,013,000   0.0%
# 26    78                        태양을 쏴라   2015.3.19      126,046,400   0.0%
# 36   251                       미궁: 비밀애   2015.4.23        2,642,000   0.0%
# 37   106                    반짝이는 박수 소리   2015.4.23       27,680,600   0.0%
# 41   231                        플랑크 상수   2015.4.30        4,953,500   0.0%
# 43    47                        다이노 타임   2015.4.30    2,108,596,800   0.2%
# 46    52                         연애의 맛    2015.5.7    1,725,990,153   0.2%
# 48    13                        악의 연대기   2015.5.14   17,361,815,332   2.0%
# ...

# %%
# 배우가 맨 앞에 있는 배역명을 기준으로 작성. 배역명이이상하면  수정 예정./정보가 없는 배역명은 '-' 으로 표시
films.iloc[0, 18] = '백보희'
films.iloc[3, 18] = '준수'
films.iloc[4, 18] = '-'
films.iloc[6, 18] = '동훈'
films.iloc[8, 18] = '두식 목소리'
films.iloc[9, 18] = '류승민'
films.iloc[10, 18] = '정남'
films.iloc[11, 18] = '이동'
films.iloc[12, 18] = '-'
films.iloc[13, 18] = '-'
films.iloc[14, 18] = '오근태'
films.iloc[15, 18] = '명탐정 김민'
films.iloc[17, 18] = '희용'
films.iloc[16, 18] = '형사'
films.iloc[18, 18] = '정석'
films.iloc[20, 18] = '김민재'
films.iloc[22, 18] = '지웅'
films.iloc[23, 18] = '태수'
films.iloc[27, 18] = '차호'
films.iloc[29, 18] = '-'
films.iloc[30, 18] = '-'
films.iloc[38, 18] = '일범'
films.iloc[35, 18] = '정우'
films.iloc[42, 18] = '자영'
films.iloc[47, 18] = '-'
films.iloc[45, 18] = '-'
films.iloc[51, 18] = '임숭재'
films.iloc[49, 18] = '초롱'
films.iloc[57, 18] = '혜정'
films.iloc[59, 18] = '강동철'
films.iloc[54, 18] = '-'
films.iloc[63, 18] = '윤영하'
films.iloc[68, 18] = '가을'
films.iloc[76, 18] = '미르목소리'
films.iloc[71, 18] = '명석'
films.iloc[78, 18] = '김민수'
films.iloc[87, 18] = '연주'
films.iloc[95, 18] = '영도'
films.iloc[105, 18] = '남복'
films.iloc[106, 18] = '강대만'
films.iloc[107, 18] = '-'
films.iloc[108, 18] = '-'
films.iloc[115, 18] = '철이'
films.iloc[116, 18] = '-'
films.iloc[123, 18] = '명환'
films.iloc[129, 18] = '김신부'
films.iloc[143, 18] = 'K'
films.iloc[144, 18] = '조진아'
films.iloc[152, 18] = '상석'
films.iloc[155, 18] = '-'
films.iloc[160, 18] = '여자'
films.iloc[161, 18] = '권기선(할머니)'
films.iloc[172, 18] = '타요목소리'
films.iloc[158, 18] = '엄홍길'
films.iloc[164, 18] = '준혁'
films.iloc[167, 18] = '-'
films.iloc[179, 18] = '-'
films.iloc[162, 18] = '환희'
films.iloc[175, 18] = '-'
films.iloc[179, 18] = '-'
films.iloc[189, 18] = '-'
films.iloc[180, 18] = '-'
films.iloc[183, 18] = '조경아'
films.iloc[193, 18] = '-'
films.iloc[208, 18] = '병천'
films.iloc[203, 18] = '진호'
films.iloc[202, 18] = '용비'
films.iloc[210, 18] = '-'
films.iloc[211, 18] = '하담'
films.iloc[214, 18] = '광수'
films.iloc[223, 18] = '공룡타르보'
films.iloc[224, 18] = '자두목소리'
films.iloc[220, 18] = '-'
films.iloc[228, 18] = '이인세'
films.iloc[236, 18] = '레나'
films.iloc[235, 18] = '김예지'
films.iloc[234, 18] = '계춘'
films.iloc[243, 18] = '엘리자구티'
films.iloc[246, 18] = '-'
films.iloc[239, 18] = '박준호'
films.iloc[240, 18] = '완주'
films.iloc[254, 18] = '곽주현'
films.iloc[255, 18] = '권지용'# 배우가 맨 앞에 있는 배역명을 기준으로 작성. 배역명이이상하면  수정 예정./정보가 없는 배역명은 '-' 으로 표시
films.iloc[0, 18] = '백보희'
films.iloc[3, 18] = '준수'
films.iloc[4, 18] = '-'
films.iloc[6, 18] = '동훈'
films.iloc[8, 18] = '두식 목소리'
films.iloc[9, 18] = '류승민'
films.iloc[10, 18] = '정남'
films.iloc[11, 18] = '이동'
films.iloc[12, 18] = '-'
films.iloc[13, 18] = '-'
films.iloc[14, 18] = '오근태'
films.iloc[15, 18] = '명탐정 김민'
films.iloc[17, 18] = '희용'
films.iloc[16, 18] = '형사'
films.iloc[18, 18] = '정석'
films.iloc[20, 18] = '김민재'
films.iloc[22, 18] = '지웅'
films.iloc[23, 18] = '태수'
films.iloc[27, 18] = '차호'
films.iloc[29, 18] = '-'
films.iloc[30, 18] = '-'
films.iloc[38, 18] = '일범'
films.iloc[35, 18] = '정우'
films.iloc[42, 18] = '자영'
films.iloc[47, 18] = '-'
films.iloc[45, 18] = '-'
films.iloc[51, 18] = '임숭재'
films.iloc[49, 18] = '초롱'
films.iloc[57, 18] = '혜정'
films.iloc[59, 18] = '강동철'
films.iloc[54, 18] = '-'
films.iloc[63, 18] = '윤영하'
films.iloc[68, 18] = '가을'
films.iloc[76, 18] = '미르목소리'
films.iloc[71, 18] = '명석'
films.iloc[78, 18] = '김민수'
films.iloc[87, 18] = '연주'
films.iloc[95, 18] = '영도'
films.iloc[105, 18] = '남복'
films.iloc[106, 18] = '강대만'
films.iloc[107, 18] = '-'
films.iloc[108, 18] = '-'
films.iloc[115, 18] = '철이'
films.iloc[116, 18] = '-'
films.iloc[123, 18] = '명환'
films.iloc[129, 18] = '김신부'
films.iloc[143, 18] = 'K'
films.iloc[144, 18] = '조진아'
films.iloc[152, 18] = '상석'
films.iloc[155, 18] = '-'
films.iloc[160, 18] = '여자'
films.iloc[161, 18] = '권기선(할머니)'
films.iloc[172, 18] = '타요목소리'
films.iloc[158, 18] = '엄홍길'
films.iloc[164, 18] = '준혁'
films.iloc[167, 18] = '-'
films.iloc[179, 18] = '-'
films.iloc[162, 18] = '환희'
films.iloc[175, 18] = '-'
films.iloc[179, 18] = '-'
films.iloc[189, 18] = '-'
films.iloc[180, 18] = '-'
films.iloc[183, 18] = '조경아'
films.iloc[193, 18] = '-'
films.iloc[208, 18] = '병천'
films.iloc[203, 18] = '진호'
films.iloc[202, 18] = '용비'
films.iloc[210, 18] = '-'
films.iloc[211, 18] = '하담'
films.iloc[214, 18] = '광수'
films.iloc[223, 18] = '공룡타르보'
films.iloc[224, 18] = '자두목소리'
films.iloc[220, 18] = '-'
films.iloc[228, 18] = '이인세'
films.iloc[236, 18] = '레나'
films.iloc[235, 18] = '김예지'
films.iloc[234, 18] = '계춘'
films.iloc[243, 18] = '엘리자구티'
films.iloc[246, 18] = '-'
films.iloc[239, 18] = '박준호'
films.iloc[240, 18] = '완주'
films.iloc[254, 18] = '곽주현'
films.iloc[255, 18] = '권지용'
films.iloc[258, 18] = '이석진'
films.iloc[259, 18] = '석우'
films.iloc[267, 18] = '석규'
films.iloc[271, 18] = '중필'
films.iloc[273, 18] = '박근형'
films.iloc[274, 18] = '텍진릭돌'
films.iloc[289, 18] = '-'
films.iloc[287, 18] = '할머니'
films.iloc[290, 18] = '소영'
films.iloc[302, 18] = '고찬근'
films.iloc[305, 18] = '이동우'
films.iloc[306, 18] = '-'
films.iloc[314, 18] = '고두식'
films.iloc[319, 18] = '형석'
films.iloc[321, 18] = '재혁'
films.iloc[329, 18] = '스피더'
films.iloc[331, 18] = '-'
films.iloc[348, 18] = '이준영'
films.iloc[336, 18] = '문영'
films.iloc[337, 18] = '강지웅'
films.iloc[340, 18] = '임청령'
films.iloc[342, 18] = '김민자'
films.iloc[352, 18] = '민식'
films.iloc[353, 18] = '인영'
films.iloc[362, 18] = '성진'
films.iloc[365, 18] = '태화'
films.iloc[372, 18] = '마리안느 스퇴거'
films.iloc[383, 18] = '한재호'
films.iloc[375, 18] = '변종구'
films.iloc[378, 18] = '빼곰 목소리'
films.iloc[371, 18] = '원술'
films.iloc[381, 18] = '미영'
films.iloc[382, 18] = '순애'
films.iloc[387, 18] = '노무현'
films.iloc[401, 18] = '-'
films.iloc[402, 18] = '-'
films.iloc[405, 18] = '박열'
films.iloc[409, 18] = '성주군민'
films.iloc[414, 18] = '이강옥'
films.iloc[417, 18] = '시형'
films.iloc[418, 18] = '기준'
films.iloc[422, 18] = '-'
films.iloc[423, 18] = '권용만'
films.iloc[424, 18] = '유진'
films.iloc[427, 18] = '강인한'
films.iloc[430, 18] = '소년'
films.iloc[431, 18] = '주진우'
films.iloc[432, 18] = '현진'
films.iloc[437, 18] = '혜미'
films.iloc[439, 18] = '안성준'
films.iloc[440, 18] = '이규호'
films.iloc[454, 18] = '김병수'
films.iloc[455, 18] = '콰지모드'
films.iloc[459, 18] = '재하'
films.iloc[460, 18] = '임태산'
films.iloc[462, 18] = '엄마'
films.iloc[467, 18] = '두식'
films.iloc[474, 18] = '도일'
films.iloc[481, 18] = '변사장'
films.iloc[482, 18] = '지영'
films.iloc[493, 18] = '옥한흠'
films.iloc[502, 18] = '대익'
films.iloc[509, 18] = '뎅이 목소리'
films.iloc[519, 18] = '미경'
films.iloc[523, 18] = '정승환'
films.iloc[526, 18] = '-'
films.iloc[528, 18] = '유정'
films.iloc[539, 18] = '덕구할배'
films.iloc[533, 18] = '철구'
films.iloc[547, 18] = '수녀 에스더'
films.iloc[556, 18] = '마크'
films.iloc[561, 18] = '위르겐힌츠페터'
films.iloc[563, 18] = '춘배'
films.iloc[581, 18] = '-'
films.iloc[584, 18] = '여은하'
films.iloc[594, 18] = '박차순'
films.iloc[596, 18] = '-'
films.iloc[602, 18] = '문회장'
films.iloc[612, 18] = '상원'
films.iloc[622, 18] = '-'
films.iloc[624, 18] = '안병남'
films.iloc[607, 18] = '료코'
films.iloc[605, 18] = '희진'
films.iloc[630, 18] = '이청'
films.iloc[638, 18] = '오영민'
films.iloc[641, 18] = '강석진'
films.iloc[640, 18] = '-'
films.iloc[639, 18] = '영주'
films.iloc[642, 18] = 'RM'
films.iloc[646, 18] = '강동철'
films.iloc[658, 18] = '나연'
films.iloc[659, 18] = '쏘남왕모스칼닷'
films.iloc[675, 18] = '박종환'
films.iloc[676, 18] = 'RM'
films.iloc[683, 18] = '박목사'
films.iloc[696, 18] = '조필호'
films.iloc[716, 18] = '심환'
films.iloc[719, 18] = '김종훈'
films.iloc[728, 18] = '노무현'
films.iloc[731, 18] = '기사선생-성민'
films.iloc[746, 18] = '이창수(아버지)'
films.iloc[764, 18] = '강유진'
films.iloc[765, 18] = '신은미'
films.iloc[769, 18] = '김강호'
films.iloc[733, 18] = '하나'
films.iloc[797, 18] = '태성'
films.iloc[799, 18] = '지석'
films.iloc[258, 18] = '이석진'
films.iloc[259, 18] = '석우'
films.iloc[267, 18] = '석규'
films.iloc[271, 18] = '중필'
films.iloc[273, 18] = '박근형'
films.iloc[274, 18] = '텍진릭돌'
films.iloc[289, 18] = '-'
films.iloc[287, 18] = '할머니'
films.iloc[290, 18] = '소영'
films.iloc[302, 18] = '고찬근'
films.iloc[305, 18] = '이동우'
films.iloc[306, 18] = '-'
films.iloc[314, 18] = '고두식'
films.iloc[319, 18] = '형석'
films.iloc[321, 18] = '재혁'
films.iloc[329, 18] = '스피더'
films.iloc[331, 18] = '-'
films.iloc[348, 18] = '이준영'
films.iloc[336, 18] = '문영'
films.iloc[337, 18] = '강지웅'
films.iloc[340, 18] = '임청령'
films.iloc[342, 18] = '김민자'
films.iloc[352, 18] = '민식'
films.iloc[353, 18] = '인영'
films.iloc[362, 18] = '성진'
films.iloc[365, 18] = '태화'
films.iloc[372, 18] = '마리안느 스퇴거'
films.iloc[383, 18] = '한재호'
films.iloc[375, 18] = '변종구'
films.iloc[378, 18] = '빼곰 목소리'
films.iloc[371, 18] = '원술'
films.iloc[381, 18] = '미영'
films.iloc[382, 18] = '순애'
films.iloc[387, 18] = '노무현'
films.iloc[401, 18] = '-'
films.iloc[402, 18] = '-'
films.iloc[405, 18] = '박열'
films.iloc[409, 18] = '성주군민'
films.iloc[414, 18] = '이강옥'
films.iloc[417, 18] = '시형'
films.iloc[418, 18] = '기준'
films.iloc[422, 18] = '-'
films.iloc[423, 18] = '권용만'
films.iloc[424, 18] = '유진'
films.iloc[427, 18] = '강인한'
films.iloc[430, 18] = '소년'
films.iloc[431, 18] = '주진우'
films.iloc[432, 18] = '현진'
films.iloc[437, 18] = '혜미'
films.iloc[439, 18] = '안성준'
films.iloc[440, 18] = '이규호'
films.iloc[454, 18] = '김병수'
films.iloc[455, 18] = '콰지모드'
films.iloc[459, 18] = '재하'
films.iloc[460, 18] = '임태산'
films.iloc[462, 18] = '엄마'
films.iloc[467, 18] = '두식'
films.iloc[474, 18] = '도일'
films.iloc[481, 18] = '변사장'
films.iloc[482, 18] = '지영'
films.iloc[493, 18] = '옥한흠'
films.iloc[502, 18] = '대익'
films.iloc[509, 18] = '뎅이 목소리'
films.iloc[519, 18] = '미경'
films.iloc[523, 18] = '정승환'
films.iloc[526, 18] = '-'
films.iloc[528, 18] = '유정'
films.iloc[539, 18] = '덕구할배'
films.iloc[533, 18] = '철구'
films.iloc[547, 18] = '수녀 에스더'
films.iloc[556, 18] = '마크'
films.iloc[561, 18] = '위르겐힌츠페터'
films.iloc[563, 18] = '춘배'
films.iloc[581, 18] = '-'
films.iloc[584, 18] = '여은하'
films.iloc[594, 18] = '박차순'
films.iloc[596, 18] = '-'
films.iloc[602, 18] = '문회장'
films.iloc[612, 18] = '상원'
films.iloc[622, 18] = '-'
films.iloc[624, 18] = '안병남'
films.iloc[607, 18] = '료코'
films.iloc[605, 18] = '희진'
films.iloc[630, 18] = '이청'
films.iloc[638, 18] = '오영민'
films.iloc[641, 18] = '강석진'
films.iloc[640, 18] = '-'
films.iloc[639, 18] = '영주'
films.iloc[642, 18] = 'RM'
films.iloc[646, 18] = '강동철'
films.iloc[658, 18] = '나연'
films.iloc[659, 18] = '쏘남왕모스칼닷'
films.iloc[675, 18] = '박종환'
films.iloc[676, 18] = 'RM'
films.iloc[683, 18] = '박목사'
films.iloc[696, 18] = '조필호'
films.iloc[716, 18] = '심환'
films.iloc[719, 18] = '김종훈'
films.iloc[728, 18] = '노무현'
films.iloc[731, 18] = '기사선생-성민'
films.iloc[746, 18] = '이창수(아버지)'
films.iloc[764, 18] = '강유진'
films.iloc[765, 18] = '신은미'
films.iloc[769, 18] = '김강호'
films.iloc[733, 18] = '하나'
films.iloc[797, 18] = '태성'
films.iloc[799, 18] = '지석'

# %%
films['배역명'].isnull().sum()
# Out:
# 261

# %%
films[films['배역명'].isnull()]
# Out:
#       순위                           영화명         개봉일              매출액 매출액점유율  \
# 19   151                개: dog eat dog    2015.3.5       11,970,000   0.0%
# 21    34                           헬머니    2015.3.5    4,120,166,972   0.5%
# 24   276                     몽골리안 프린세스   2015.3.19        3,254,000   0.0%
# 25   109                     그라운드의 이방인   2015.3.19       26,013,000   0.0%
# 26    78                        태양을 쏴라   2015.3.19      126,046,400   0.0%
# 36   251                       미궁: 비밀애   2015.4.23        2,642,000   0.0%
# 37   106                    반짝이는 박수 소리   2015.4.23       27,680,600   0.0%
# 41   231                        플랑크 상수   2015.4.30        4,953,500   0.0%
# 43    47                        다이노 타임   2015.4.30    2,108,596,800   0.2%
# 46    52                         연애의 맛    2015.5.7    1,725,990,153   0.2%
# 48    13                        악의 연대기   2015.5.14   17,361,815,332   2.0%
# ...

# %% [markdown]
# 컬럼이 너무 길어서 검색이 어려움을 겪고 df 데이터를 만들었음.
# 컬럼명을 삭제 후, 작업 할 예정. test파일이라고 생각하면 될 듯.

# %%
df=films.drop(['관객수', '순위', '영화코드', '배우코드','매출액', '매출액점유율', '누적매출액', '스크린수', '대표국적', '국적', '장르', '상영횟수', '제작사', '배급사', '등급', '누적관객수'], axis=1)

# %%
df.sample()
# Out:
#                   영화명        개봉일      감독                          배우  배역명  \
# 766  안녕, 티라노: 영원히, 함께  2019.8.14  시즈노 코분  시영준,정혜원,이세은,이현,김지혜,박영진,김준현  티라노
#
#     주연배우  역할 배우성별
# 766  시영준  배우   남자

# %%
df[df['배역명'].isnull()]
# Out:
#                               영화명         개봉일                감독  \
# 19                 개: dog eat dog    2015.3.5            황욱,박민우
# 21                            헬머니    2015.3.5               신한솔
# 24                      몽골리안 프린세스   2015.3.19               정단우
# 25                      그라운드의 이방인   2015.3.19               김명준
# 26                         태양을 쏴라   2015.3.19               김태식
# 36                        미궁: 비밀애   2015.4.23            조조 히데오
# 37                     반짝이는 박수 소리   2015.4.23              이길보라
# 41                         플랑크 상수   2015.4.30               조성규
# 43                         다이노 타임   2015.4.30         최윤석,존 카프카
# 46                          연애의 맛    2015.5.7               김아론
# 48                         악의 연대기   2015.5.14               백운학
# 52                            무뢰한   2015.5.27               오승욱
# 62                           소수의견   2015.6.24               김성제
# 65                      나의 절친 악당들   2015.6.25               임상수
# ...

# %% [markdown]
# # films_edit 작업
# films_edit 파일을 받아서 fims파일이 아닌 films_edit에 작업함.

# %%
films_ = pd.read_excel('../01.Data_Collection/films_edit.xlsx')

# %%
films_.head()
# Out:
#       순위       영화명      영화코드         개봉일          매출액 매출액점유율        누적매출액  \
# 0   55.0       워킹걸  20147947  2015-01-07   1183887479   0.1%   1201963479
# 1  121.0        설해  20124398  2015-01-08     20767500   0.0%     29770500
# 2   26.0       허삼관  20131262  2015-01-14   7408943569   0.8%   7408943569
# 3   16.0    오늘의 연애  20142407  2015-01-14  14924654487   1.7%  14924654487
# 4  149.0  꽃보다 처녀귀신  20155744  2015-01-15      7909000   0.0%      7909000
#
#        관객수    누적관객수  스크린수   상영횟수 대표국적  국적                제작사  \
# 0   149181   151550   308   7076   한국  한국      (주)홍필름,(주)수필름
# 1     2796     3933    34    335   한국  한국           (주)맑음영화사
# 2   955679   955679   621  27645   한국  한국  (주)두타연,(주)판타지오픽쳐스
# 3  1891993  1891993   709  47237   한국  한국          (주)팝콘에프앤엠
# 4     1567     1567     5     42   한국  한국        고구마콘텐츠허브(주)
#
#                          배급사        등급          장르  F-rated   감독 대표감독  \
# 0              메가박스중앙(주)플러스엠   청소년관람불가  코미디,멜로/로맨스        1  정범식  정범식
# ...

# %%
films_.isnull().sum()
# Out:
# 순위            2
# 영화명           0
# 영화코드          0
# 개봉일           0
# 매출액           0
# 매출액점유율        2
# 누적매출액         0
# 관객수           0
# 누적관객수         0
# 스크린수          0
# 상영횟수          0
# 대표국적          2
# 국적            2
# 제작사          22
# 배급사           3
# 등급            2
# 장르            2
# F-rated       0
# 감독            3
# 대표감독          3
# 감독코드          3
# 감독성별          5
# 감독_대표역할       3
# 감독필모          3
# 작가          103
# 대표작가        103
# 대표작가(필명)    103
# 작가코드        103
# 작가성별        136
# 작가_대표역할     103
# 작가필모        103
# 배우            0
# 주연배우          0
# 배역명         452
# 배우코드          0
# 배우성별         18
# 배우_대표역할       0
# 배우필모         71
# dtype: int64

# %% [markdown]
# # films_edit 배역명 넣기

# %%
films_[films_['배역명'].isnull()]
# Out:
#         순위          영화명      영화코드         개봉일          매출액 매출액점유율  \
# 0     55.0          워킹걸  20147947  2015-01-07   1183887479   0.1%
# 3     16.0       오늘의 연애  20142407  2015-01-14  14924654487   1.7%
# 4    149.0     꽃보다 처녀귀신  20155744  2015-01-15      7909000   0.0%
# 5    119.0      고양이 장례식  20144601  2015-01-15     23200900   0.0%
# 8    111.0      생각보다 맑은  20145202  2015-01-22     27393900   0.0%
# ..     ...          ...       ...         ...          ...    ...
# 785  163.0       불빛 아래서  20173383  2019-08-29      6427700   0.0%
# 788  105.0        동물, 원  20189647  2019-09-05     25257880   0.0%
# 803  106.0  나의 노래는 멀리멀리  20193928  2019-10-03     28495080   0.0%
# 805   87.0       수상한 이웃  20183848  2019-10-09     58134640   0.0%
# 807  463.0       여수 밤바다  20174266  2019-10-10       848100   0.0%
#
#            누적매출액      관객수    누적관객수  스크린수   상영횟수 대표국적  국적               제작사  \
# 0     1201963479   149181   151550   308   7076   한국  한국     (주)홍필름,(주)수필름
# ...

# %%
# 실험.
films_.iloc[0, -5] = '백보희'

# %%
# 잘 들어감
films_.head()
# Out:
#       순위       영화명      영화코드         개봉일          매출액 매출액점유율        누적매출액  \
# 0   55.0       워킹걸  20147947  2015-01-07   1183887479   0.1%   1201963479
# 1  121.0        설해  20124398  2015-01-08     20767500   0.0%     29770500
# 2   26.0       허삼관  20131262  2015-01-14   7408943569   0.8%   7408943569
# 3   16.0    오늘의 연애  20142407  2015-01-14  14924654487   1.7%  14924654487
# 4  149.0  꽃보다 처녀귀신  20155744  2015-01-15      7909000   0.0%      7909000
#
#        관객수    누적관객수  스크린수   상영횟수 대표국적  국적                제작사  \
# 0   149181   151550   308   7076   한국  한국      (주)홍필름,(주)수필름
# 1     2796     3933    34    335   한국  한국           (주)맑음영화사
# 2   955679   955679   621  27645   한국  한국  (주)두타연,(주)판타지오픽쳐스
# 3  1891993  1891993   709  47237   한국  한국          (주)팝콘에프앤엠
# 4     1567     1567     5     42   한국  한국        고구마콘텐츠허브(주)
#
#                          배급사        등급          장르  F-rated   감독 대표감독  \
# 0              메가박스중앙(주)플러스엠   청소년관람불가  코미디,멜로/로맨스        1  정범식  정범식
# ...

# %%
# 배우가 맨 앞에 있는 배역명을 기준으로 작성. 배역명이이상하면  수정 예정./정보가 없는 배역명은 '-' 으로 표시
films_.iloc[3, -5] = '준수'
films_.iloc[4, -5] = '-'
films_.iloc[6, -5] = '동훈'
films_.iloc[8, -5] = '두식 목소리'
films_.iloc[9, -5] = '류승민'
films_.iloc[10, -5] = '정남'
films_.iloc[11, -5] = '이동'
films_.iloc[12, -5] = '-'
films_.iloc[13, -5] = '-'
films_.iloc[14, -5] = '오근태'
films_.iloc[15, -5] = '명탐정 김민'
films_.iloc[17, -5] = '희용'
films_.iloc[16, -5] = '형사'
films_.iloc[18, -5] = '정석'
films_.iloc[20, -5] = '김민재'
films_.iloc[22, -5] = '지웅'
films_.iloc[23, -5] = '태수'
films_.iloc[27, -5] = '차호'
films_.iloc[29, -5] = '-'
films_.iloc[30, -5] = '-'
films_.iloc[38, -5] = '일범'
films_.iloc[35, -5] = '정우'
films_.iloc[42, -5] = '자영'
films_.iloc[47, -5] = '-'
films_.iloc[45, -5] = '-'
#pip install openpyxl

# %%
# 엑셀 올리는 방법
#films_.to_excel('../01.Data_Collection/films_edit.xlsx', index=False)

# %%
films_[films_['배역명'].isnull()]
# Out:
#         순위             영화명      영화코드         개봉일         매출액 매출액점유율  \
# 5    119.0         고양이 장례식  20144601  2015-01-15    23200900   0.0%
# 19   151.0  개: dog eat dog  20143252  2015-03-05    11970000   0.0%
# 21    34.0             헬머니  20148841  2015-03-05  4120166972   0.5%
# 24   276.0       몽골리안 프린세스  20155926  2015-03-19     3254000   0.0%
# 25   109.0       그라운드의 이방인  20134800  2015-03-19    26013000   0.0%
# ..     ...             ...       ...         ...         ...    ...
# 785  163.0          불빛 아래서  20173383  2019-08-29     6427700   0.0%
# 788  105.0           동물, 원  20189647  2019-09-05    25257880   0.0%
# 803  106.0     나의 노래는 멀리멀리  20193928  2019-10-03    28495080   0.0%
# 805   87.0          수상한 이웃  20183848  2019-10-09    58134640   0.0%
# 807  463.0          여수 밤바다  20174266  2019-10-10      848100   0.0%
#
#           누적매출액     관객수   누적관객수  스크린수   상영횟수 대표국적  국적  \
# 5      23200900    2865    2865    46    394   한국  한국
# ...

# %%
# 배우가 맨 앞에 있는 배역명을 기준으로 작성. 배역명이이상하면  수정 예정./정보가 없는 배역명은 '-' 으로 표시
films_.iloc[19, -5] = '형신'
films_.iloc[21, -5] = '헬머니'
films_.iloc[24, -5] = '단우'
films_.iloc[36, -5] = '-'
films_.iloc[37, -5] = '이상국 아빠'
films_.iloc[26, -5] = '존'
films_.iloc[41, -5] = '김우주'
films_.iloc[46, -5] = '왕성기'
films_.iloc[62, -5] = '진원'
films_.iloc[69, -5] = '-'
films_.iloc[74, -5] = '-'
films_.iloc[73, -5] = '양범조'
films_.iloc[80, -5] = '-'
films_.iloc[82, -5] = '강타'
films_.iloc[83, -5] = '-'
films_.iloc[84, -5] = '수남'
films_.iloc[86, -5] = '연우'
films_.iloc[92, -5] = '이미례'
films_.iloc[100, -5] = '성철'
films_.iloc[120, -5] = '고동호'
films_.iloc[125, -5] = '-'
films_.iloc[121, -5] = '-'
films_.iloc[127, -5] = '시운'
films_.iloc[130, -5] = '경수'
films_.iloc[132, -5] = '강만'
films_.iloc[134, -5] = '-'
films_.iloc[88, -5] = '신진명'
films_.iloc[90, -5] = '이정진'
films_.iloc[101, -5] = '영조'
films_.iloc[102, -5] = '시나리오 작가, 정민'
films_.iloc[104, -5] = '함춘수'
films_.iloc[111, -5] = '혜연'
films_.iloc[112, -5] = '-'
films_.iloc[117, -5] = '조명부 퍼스트'
films_.iloc[122, -5] = '강자겸'
films_.iloc[126, -5] = '아영'
films_.iloc[135, -5] = '-'
films_.iloc[142, -5] = '-'
films_.iloc[145, -5] = '동완'
films_.iloc[146, -5] = '-'
films_.iloc[149, -5] = '정훈'
films_.iloc[151, -5] = '한동민'
films_.iloc[157, -5] = '천막덕'
films_.iloc[170, -5] = '배수정'
films_.iloc[185, -5] = '-'
films_.iloc[187, -5] = '범실'
films_.iloc[191, -5] = '상민'
films_.iloc[192, -5] = '수하'
films_.iloc[199 -5] = '이진상'
films_.iloc[780, -5] = '김정호'
films_.iloc[794, -5] = '김지희'

# %%
films_['배역명'].isnull().sum()
# Out:
# 196

# %%
films_.head()
# Out:
#     순위       영화명      영화코드         개봉일          매출액 매출액점유율        누적매출액  \
# 0   55       워킹걸  20147947  2015-01-07   1183887479   0.1%   1201963479
# 1  121        설해  20124398  2015-01-08     20767500   0.0%     29770500
# 2   26       허삼관  20131262  2015-01-14   7408943569   0.8%   7408943569
# 3   16    오늘의 연애  20142407  2015-01-14  14924654487   1.7%  14924654487
# 4  149  꽃보다 처녀귀신  20155744  2015-01-15      7909000   0.0%      7909000
#
#        관객수    누적관객수 스크린수   상영횟수 대표국적  국적                제작사  \
# 0   149181   151550  308   7076   한국  한국      (주)홍필름,(주)수필름
# 1     2796     3933   34    335   한국  한국           (주)맑음영화사
# 2   955679   955679  621  27645   한국  한국  (주)두타연,(주)판타지오픽쳐스
# 3  1891993  1891993  709  47237   한국  한국          (주)팝콘에프앤엠
# 4     1567     1567    5     42   한국  한국        고구마콘텐츠허브(주)
#
#                          배급사        등급          장르 F-rated   감독 대표감독  \
# 0              메가박스중앙(주)플러스엠   청소년관람불가  코미디,멜로/로맨스       1  정범식  정범식
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_row', None)

# %%
films_[films_['배역명'].isnull()]
# Out:
#       순위                           영화명      영화코드         개봉일          매출액  \
# 5    119                       고양이 장례식  20144601  2015-01-15     23200900
# 25   109                     그라운드의 이방인  20134800  2015-03-19     26013000
# 34    88                           검은손  20157986  2015-04-16     89815665
# 43    47                        다이노 타임  20100211  2015-04-30   2108596800
# 52    39                           무뢰한  20130566  2015-05-27   3262207431
# 65    58                     나의 절친 악당들  20142856  2015-06-25   1054470664
# 70    29                            손님  20148844  2015-07-09   6385937880
# 81    68                   성실한 나라의 앨리스  20156281  2015-08-13    349482500
# 85    71                  에스엠타운 더 스테이지  20152870  2015-08-13    284650500
# 91    37                           오피스  20143511  2015-09-03   3460460230
# 93   261              자가당착: 시대정신과 현실참여  20101244  2015-09-10      3001000
# 94   116                            영도  20141610  2015-09-10     24304000
# ...

# %%
films_[films_['작가'].isnull()]
# Out:
#       순위                           영화명      영화코드         개봉일         매출액  \
# 6    113                       미라클 여행기  20148631  2015-01-15    20562500
# 14   123                      망원동 인공위성  20133803  2015-02-05    19509200
# 26    78                        태양을 쏴라  20151582  2015-03-19   126046400
# 35   317           다이빙벨: 진실은 침몰하지 않습니다  20158943  2015-04-16     2209000
# 38   106                    반짝이는 박수 소리  20148982  2015-04-23    27680600
# 46    92               명량: 회오리 바다를 향하여  20157431  2015-05-07    64170500
# 48   143                      명령불복종 교사  20143726  2015-05-14    11349000
# 56   104                      마이 페어 웨딩  20141705  2015-06-04    34708000
# 84    81                            순교  20158951  2015-08-13   115342000
# 85    71                  에스엠타운 더 스테이지  20152870  2015-08-13   284650500
# 86    83                          위로공단  20141702  2015-08-13   106504000
# 92    93                       기적의 피아노  20153311  2015-09-03    63003800
# ...

# %%
films_.to_excel('../01.Data_Collection/films_edit.xlsx', index=False)

# %%
films_['배역명'].isnull().sum()
# Out:
# 196
