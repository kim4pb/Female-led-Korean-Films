# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# plot 한글출력
plt.rcParams['font.family'] = 'NanumGothic'

# warning message 제거
import warnings
warnings.filterwarnings('ignore')

# %%
# 컬럼명 오류로 인해,,,,한국어로 인코딩을 함.. 하지만 결국 안됨.
audits = pd.read_csv('../movie_data/audits.csv' ,encoding = 'utf-8')
boxoffice = pd.read_csv('../movie_data/boxoffice.csv' ,encoding = 'utf-8')
companys= pd.read_csv('../movie_data/companys.csv' ,encoding = 'utf-8')
show_time= pd.read_csv('../movie_data/show_time.csv' ,encoding = 'utf-8')

# %%
audits.head()
# Out:
#          auditNo   movieCd watchGradeNm
# 0  2014-MF01401   20148048     15세이상관람가
# 1  2015-MF00751   20148851     15세이상관람가
# 2  2015-MF01214   20149314      청소년관람불가
# 3  2015-MF01188   20145503     15세이상관람가
# 4  2015-MF01012   20148846     12세이상관람가

# %%
audits
# Out:
#            auditNo   movieCd watchGradeNm
# 0    2014-MF01401   20148048     15세이상관람가
# 1    2015-MF00751   20148851     15세이상관람가
# 2    2015-MF01214   20149314      청소년관람불가
# 3    2015-MF01188   20145503     15세이상관람가
# 4    2015-MF01012   20148846     12세이상관람가
# ..             ...       ...          ...
# 803   2019-MF01498  20188750     15세이상관람가
# 804   2019-MF00326  20176103     15세이상관람가
# 805   2019-MF00595  20183782     15세이상관람가
# 806   2019-MF01369  20184621     12세이상관람가
# 807   2018-MF02462  20182530     15세이상관람가
#
# [808 rows x 3 columns]

# %%
audits.isnull().sum()
# Out:
# auditNo         0
# movieCd         0
# watchGradeNm    0
# dtype: int64

# %%
show_time.head()
# Out:
#     movieCd  showTm
# 0  20148048   123.0
# 1  20148851   139.0
# 2  20149314   130.0
# 3  20145503   108.0
# 4  20148846   125.0

# %%
show_time
# Out:
#       movieCd  showTm
# 0    20148048   123.0
# 1    20148851   139.0
# 2    20149314   130.0
# 3    20145503   108.0
# 4    20148846   125.0
# ..        ...     ...
# 801  20188750   114.0
# 802  20176103   115.0
# 803  20183782   131.0
# 804  20184621   103.0
# 805  20182530   111.0
#
# [806 rows x 2 columns]

# %%
audits.isnull().sum()
# Out:
# auditNo         0
# movieCd         0
# watchGradeNm    0
# dtype: int64

# %%
companys
# Out:
#       companyCd     companyNm companyPartNm   movieCd
# 0      20100374       (주)외유내강           제작사  20148048
# 1      20186561       (주)필름케이           제작사  20148048
# 2      20110854     씨제이이앤엠(주)           배급사  20148048
# 3      20110854     씨제이이앤엠(주)            제공  20148048
# 4      20100109     씨제이엔터테인먼트        해외세일즈사  20148048
# ...         ...           ...           ...       ...
# 3075   20156628  영화사 해그림 주식회사           제작사  20182530
# 3076   20110854     씨제이이앤엠(주)           제작사  20182530
# 3077   20110854     씨제이이앤엠(주)           배급사  20182530
# 3078   20110854     씨제이이앤엠(주)            제공  20182530
# 3079   20100109     씨제이엔터테인먼트        해외세일즈사  20182530
#
# [3080 rows x 4 columns]

# %%
companys.isnull().sum()
# Out:
# companyCd        0
# companyNm        0
# companyPartNm    0
# movieCd          0
# dtype: int64

# %%
companys['companyNm'].unique()
# Out:
# array(['(주)외유내강', '(주)필름케이', '씨제이이앤엠(주)', '씨제이엔터테인먼트', '(주)포스크리에이티브파티',
#        '(주)케이퍼필름', '(주)쇼박스', '(주)인터파크', '(유)내부자들 문화전문회사', '영화사 집',
#        '오퍼스픽쳐스(유)', '유나이티드픽처스(주)', '(주)타이거픽쳐스', '(주)로제타시네마',
#        '(주)넥스트엔터테인먼트월드(NEW)', 'IBK 기업은행', 'IBK캐피탈', '(주)콘텐츠판다', '(주)영화나무',
#        '(주)아이에이치큐', '(주)제이케이필름', '청년필름(주)', '디지털 아이디어', '(주)제이콘컴퍼니',
#        '(주)영화사 신세계', '(주)비에이엔터테인먼트', '(주)크리픽쳐스', '(주)미스터로맨스', '(주)모베라픽처스',
#        '(주)빅픽쳐', '(주)용필름', '유한회사 제이필름', '(주)무브픽쳐스', '(주)팝콘에프앤엠',
#        '폴룩스픽쳐스(주)', 'CGV아트하우스', '(주)수필름', '롯데쇼핑㈜롯데엔터테인먼트', '(주)화인컷',
#        '(주)사나이픽처스', '상상필름(주)', '(주)영화사 빛나는 제국', '우수영화사', '(주)미인픽쳐스',
#        '씨네그루(주)다우기술', '(주)엠라인디스트리뷰션', '(주)우주필름', '(주)뱅가드스튜디오',
#        '반짝반짝영화사(주)', '(주)영화사아이비젼', '메가박스중앙(주)플러스엠', '산수벤처스',
#        '타임와이즈인베스트먼트(주)', '(주)미디어로그', '(주)우리인베스트먼트', '(주)파인컴퍼니', '(주)두타연',
#        '(주)판타지오픽쳐스', '(주)전망좋은 영화사', 'TCO(주)더콘텐츠온', '캐피탈원(주)',
#        '(주)대교인베스트먼트', '(주)화인웍스', '(주)키메이커', '(주)유비유필름', '(주)주피터필름',
# ...

# %%
pd.DataFrame(companys['companyNm'].unique())
# Out:
#                  0
# 0          (주)외유내강
# 1          (주)필름케이
# 2        씨제이이앤엠(주)
# 3        씨제이엔터테인먼트
# 4    (주)포스크리에이티브파티
# ..             ...
# 769        (주)에코필름
# 770          필름모멘텀
# 771    (주)다나크리에이티브
# 772  (주)에이스메이커무비웍스
# 773   영화사 해그림 주식회사
#
# [774 rows x 1 columns]

# %%
boxoffice.head()
# Out:
#     순위       영화명        개봉일            매출액  매출액점유율          누적매출액        관객수   \
# 0   55       워킹걸   2015.1.7   1,183,887,479   0.1%   1,201,963,479    149,181
# 1  121        설해   2015.1.8      20,767,500   0.0%      29,770,500      2,796
# 2   26       허삼관  2015.1.14   7,408,943,569   0.8%   7,408,943,569    955,679
# 3   16    오늘의 연애  2015.1.14  14,924,654,487   1.7%  14,924,654,487  1,891,993
# 4  149  꽃보다 처녀귀신  2015.1.15       7,909,000   0.0%       7,909,000      1,567
#
#       누적관객수  스크린수    상영횟수  대표국적  국적                제작사   \
# 0    151,550   308   7,076    한국  한국      (주)홍필름,(주)수필름
# 1      3,933    34     335    한국  한국           (주)맑음영화사
# 2    955,679   621  27,645    한국  한국  (주)두타연,(주)판타지오픽쳐스
# 3  1,891,993   709  47,237    한국  한국          (주)팝콘에프앤엠
# 4      1,567     5      42    한국  한국        고구마콘텐츠허브(주)
#
#                         배급사        등급          장르   감독   \
# 0              메가박스중앙(주)플러스엠   청소년관람불가  코미디,멜로/로맨스  정범식
# ...

# %% [markdown]
# # boxoffice null 값 채우기

# %%
# boxoffice에 null 값이 있기 때문에 채워넣음.
boxoffice.isnull().sum()
# Out:
# 순위         0
# 영화명        0
# 개봉일        0
# 매출액        0
# 매출액점유율     0
# 누적매출액      0
# 관객수        0
# 누적관객수      0
# 스크린수       0
# 상영횟수       0
# 대표국적       0
# 국적         0
# 제작사       20
# 배급사        1
# 등급         0
# 장르         0
# 감독         3
# 배우        31
# dtype: int64

# %%
# 컬럼명 지정할려고 했으나 실패 -> 에러: 'set' object is not callable
#boxoffice = boxoffice.rename(columns={'순위' , '영화명', '개봉일', '매출액', '매출액점유율', '누적매출액', '관객수', '누적관객수', '스크린수', '상영횟수', '대표국적', '국적', '제작사', '배급사', '등급', '장르', '감독', '배우'})
#boxoffice['배우'].unique()
#boxoffice['배우']
#boxoffice[boxoffice['배우'].isnull()]
# boxoffice[boxoffice.배우.isnull()]
# -> 데이터 타입을 확인하지 않아서 나타난 실수로 확인.

# %%
# 컬럼명이 한국어라서 인식하지 못하는 것 같아 컬럼 명을 영어로 변경함...
boxoffice = pd.read_csv('../movie_data/boxoffice_en.csv')

# %%
boxoffice.head()
# Out:
#    rank   movieNm opening day           sales sales share       Acc sales  \
# 0    55       워킹걸    2015.1.7   1,183,887,479       0.10%   1,201,963,479
# 1   121        설해    2015.1.8      20,767,500       0.00%      29,770,500
# 2    26       허삼관   2015.1.14   7,408,943,569       0.80%   7,408,943,569
# 3    16    오늘의 연애   2015.1.14  14,924,654,487       1.70%  14,924,654,487
# 4   149  꽃보다 처녀귀신   2015.1.15       7,909,000       0.00%       7,909,000
#
#   Nu viewers Acc viewers Nu of screens Nu show representative country  \
# 0    149,181     151,550           308   7,076                     한국
# 1      2,796       3,933            34     335                     한국
# 2    955,679     955,679           621  27,645                     한국
# 3  1,891,993   1,891,993           709  47,237                     한국
# 4      1,567       1,567             5      42                     한국
#
#   nationality production company                distributor watchGradeNm  \
# ...

# %%
# actor 컬럼이 생겨서 삭제.
boxoffice.drop(['actor'], axis='columns', inplace=True)

# %%
boxoffice[boxoffice['cast'].isnull()]
# Out:
#      rank    movieNm opening day        sales sales share    Acc sales  \
# 455    93  노트르담 드 파리   2017.11.1  115,659,500       0.00%  115,659,500
#
#     Nu viewers Acc viewers Nu of screens Nu show representative country  \
# 455      9,085       9,085            36     843                     한국
#
#     nationality production company distributor watchGradeNm   genre director  \
# 455          한국            (주)패뷸러스     (주)패뷸러스        전체관람가  뮤지컬,공연      정성복
#
#     cast
# 455  NaN

# %%
# 검색해서 넣었으나 actor이 안들어감....왜 안들어가는지 모르겠음. 
boxoffice.loc[boxoffice['rank'] == '317', 'cast'] = '이종인'

# %%
boxoffice[boxoffice['rank']==317]
# Out:
#     rank              movieNm opening day      sales sales share  Acc sales  \
# 34   317  다이빙벨: 진실은 침몰하지 않습니다   2015.4.16  2,209,000       0.00%  2,209,000
#
#    Nu viewers Acc viewers Nu of screens Nu show representative country  \
# 34        300         300             4      58                     한국
#
#    nationality production company distributor watchGradeNm  genre director  \
# 34          한국     아시아프레스,(주)씨네포트     (주)시네마달     15세이상관람가  다큐멘터리  이상호,안해룡
#
#    cast
# 34  이종인

# %%
# 이렇게 하니까 들어감...도대체 왜 들어가는거야...
boxoffice.iloc[34, 17] = '이종인'

# %%
boxoffice[boxoffice['rank']==317]
# Out:
#     rank              movieNm opening day      sales sales share  Acc sales  \
# 34   317  다이빙벨: 진실은 침몰하지 않습니다   2015.4.16  2,209,000       0.00%  2,209,000
#
#    Nu viewers Acc viewers Nu of screens Nu show representative country  \
# 34        300         300             4      58                     한국
#
#    nationality production company distributor watchGradeNm  genre director  \
# 34          한국     아시아프레스,(주)씨네포트     (주)시네마달     15세이상관람가  다큐멘터리  이상호,안해룡
#
#    cast
# 34  이종인

# %%
boxoffice.iloc[34]
# Out:
# rank                                      317
# movieNm                   다이빙벨: 진실은 침몰하지 않습니다
# opening day                         2015.4.16
# sales                               2,209,000
# sales share                             0.00%
# Acc sales                           2,209,000
# Nu viewers                                300
# Acc viewers                               300
# Nu of screens                               4
# Nu show                                    58
# representative country                     한국
# nationality                                한국
# production company             아시아프레스,(주)씨네포트
# distributor                           (주)시네마달
# watchGradeNm                         15세이상관람가
# genre                                   다큐멘터리
# director                              이상호,안해룡
# cast                                      이종인
# Name: 34, dtype: object

# %% [markdown]
# # 영화배우 null 채우기

# %%
# 영화 배우 이름 찾아서 넣음. 배우 정보가 없는 영화는 '-' 로 표시함. 
boxoffice.iloc[44, 17] = '황윤'
boxoffice.iloc[74, 17] = '김말해, 박은순, 손희경, 김영자'
boxoffice.iloc[82, 17] = '강타, 보아, 동방신기, 소녀시대, 샤이니, 에프엑스, 레드벨벳'
boxoffice.iloc[116, 17] = '-'
boxoffice.iloc[125, 17] = '도꾜 조선 중고급학교 권투부, 김상수'
boxoffice.iloc[150, 17] = '윤기진, 황선, 윤민, 윤겨레'
boxoffice.iloc[161, 17] = '권기선, 이준교'
boxoffice.iloc[168, 17] = '-'
boxoffice.iloc[172, 17] = '문남숙, 정혜옥, 최하나, 김영선, 전숙경, 김은아, 엄상현, 신용우'
boxoffice.iloc[233, 17] = '이종락'
boxoffice.iloc[243, 17] = '엘리자 구티, 아니카 쾀보카'
boxoffice.iloc[257, 17] = '엄상현, 이선호, 미야케켄타, 코지로치에, 아스미카나'
boxoffice.iloc[269, 17] = '김진숙, 박성호, 박희찬, 윤국성, 정태훈, 김지연, 정이균'
boxoffice.iloc[279, 17] = '상현, 정선, 복수, 진태'
boxoffice.iloc[292, 17] = '아케사카 사토미, 아스미 카나, 치바 스스무, 고토 사오리, 하라 사유리, 이토 카나에, 카키하라 테츠야, 카토 에미리'
boxoffice.iloc[302, 17] = '고찬근, 오은규, 황건, 트리오 오원, 채재일'
boxoffice.iloc[306, 17] = '소 알로이시오'
boxoffice.iloc[393, 17] = '-'
boxoffice.iloc[401, 17] = '배미영, 이수미, 김정숙, 이희동, 배정하, 이국민, 배은하'
boxoffice.iloc[412, 17] = '-'
boxoffice.iloc[413, 17] = '이묵, 논, 텐, 이영'
boxoffice.iloc[441, 17] = '파드마 앙뚜, 우르갼 릭젠'
boxoffice.iloc[445, 17] = '안젤로 델 베키오, 히바 티와지, 리챠드 샤레스, 다니엘 라부아, 마틴자루, 알리제 라랑드, 제이'
boxoffice.iloc[486, 17] = '종호, 이자은, 김하림, 백마리, 강주리'
boxoffice.iloc[509, 17] = '배정미, 김선혜, 서지연, 사성웅, 전태열, 안용욱'
boxoffice.iloc[596, 17] = '-'
boxoffice.iloc[640, 17] = '-'
boxoffice.iloc[719, 17] = '김종훈, 최국인, 지나이다 이바노브나, 한 아드레이, 한지마, 문 빅토르, 좌바예프 무싸베코프'
boxoffice.iloc[756, 17] = '-'
boxoffice.iloc[777, 17] = '김내현, 김진규, 이민우, 최민규, 안지, 김영진, 백선혁, 정유겸'

# %%
boxoffice[boxoffice['rank']==118]
# Out:
#      rank             movieNm opening day       sales sales share   Acc sales  \
# 74    118              밀양 아리랑   2015.7.16  17,404,000       0.00%  17,824,000
# 247   118                  삼례   2016.6.23  24,092,600       0.00%  24,191,600
# 413   118              불온한 당신   2017.7.20  30,199,500       0.00%  34,220,700
# 549   118                 수성못   2018.4.19  26,232,400       0.00%  28,338,900
# 719   118  굿바이 마이 러브NK: 붉은 청춘    2019.5.2  15,834,280       0.00%  16,836,280
#
#     Nu viewers Acc viewers Nu of screens Nu show representative country  \
# 74       2,870       2,950            14     257                     한국
# 247      3,244       3,264            26     362                     한국
# 413      4,028       4,729            14     436                     한국
# 549      3,550       3,806            36     523                     한국
# 719      2,175       2,320            19     267                     한국
#
# ...

# %% [markdown]
# # 제작사 넣기

# %%
boxoffice[boxoffice['production company'].isnull()]
# Out:
#      rank  movieNm opening day       sales sales share   Acc sales Nu viewers  \
# 617   133  나부야 나부야   2018.9.20  15,062,400       0.00%  15,062,400      2,789
# 690   127    국경의 왕   2019.2.28  12,042,500       0.00%  14,272,900      1,698
#
#     Acc viewers Nu of screens Nu show representative country nationality  \
# 617       2,789            19     433                     한국          한국
# 690       2,057             7     204                     한국          한국
#
#     production company          distributor watchGradeNm  genre director  \
# 617                NaN               ㈜인디스토리        전체관람가  다큐멘터리      최정우
# 690                NaN  무브먼트,독립영화전용관 인디스페이스     15세이상관람가    드라마      임정환
#
#                                cast
# 617                         이종수,김순규
# 690  김새벽,조현철,정혁기,박진수,이유진,임철,박상용,임정환

# %%
# 제작사 찾아서 넣음. 제작사 정보가 없는 영화는 '-' 로 표시함. 
boxoffice.iloc[252, 12] = '-'
boxoffice.iloc[336, 12] = '-'
boxoffice.iloc[394, 12] = '-'
boxoffice.iloc[406, 12] = '-'
boxoffice.iloc[450, 12] = '-'
boxoffice.iloc[500, 12] = '-'
boxoffice.iloc[575, 12] = '-'
boxoffice.iloc[628, 12] = '-'
boxoffice.iloc[640, 12] = '-'
boxoffice.iloc[645, 12] = 'KARTS 영주프로덕션'
boxoffice.iloc[660, 12] = '-'
boxoffice.iloc[689, 12] = '-'
boxoffice.iloc[691, 12] = '전태일 47주기 대구시민 노동문화제 , 독립영화전용관 오오극장 , 민예총 대구지회'
boxoffice.iloc[706, 12] = '영화사 책방'
boxoffice.iloc[731, 12] = '-'
boxoffice.iloc[740, 12] = '-'
boxoffice.iloc[759, 12] = '-'
boxoffice.iloc[794, 12] = '시소'

# %% [markdown]
# # 배급사 넣기

# %%
# 배급사 NULL 값 확인.
boxoffice[boxoffice['distributor'].isnull()]
# Out:
# Empty DataFrame
# Columns: [rank, movieNm, opening day, sales, sales share, Acc sales, Nu viewers, Acc viewers, Nu of screens, Nu show, representative country, nationality, production company, distributor, watchGradeNm, genre, director, cast]
# Index: []

# %%
# 배급사 정보를 찾아서 채움. 하지만 배급사 정보가 없어서 '-' 입력.
boxoffice.iloc[638, 13] = '-'

# %% [markdown]
# # 감독 넣기

# %%
# 감독 정보 없는 것은 '-' 표시.(가수 다큐 영화? 라서 감독 없음.)
boxoffice[boxoffice['director'].isnull()]
# Out:
# Empty DataFrame
# Columns: [rank, movieNm, opening day, sales, sales share, Acc sales, Nu viewers, Acc viewers, Nu of screens, Nu show, representative country, nationality, production company, distributor, watchGradeNm, genre, director, cast]
# Index: []

# %%
# 감독 정보가 없어서 '-' 넣음. 
boxoffice.iloc[499, 16] = '-'
boxoffice.iloc[658, 16] = '-'
boxoffice.iloc[676, 16] = '-'

# %%
boxoffice.to_csv('../boxoffice_en.csv', index=False)
