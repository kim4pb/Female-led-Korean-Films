# %%
import pandas as pd
import datetime
# import numpy as np

# import matplotlib
# import matplotlib.pyplot as plt
# import seaborn as sns
# import plotly.express as px
# import plotly.graph_objects as go

# # 전체 컬럼, 전체 행, 전체 숫자 출력
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# pd.set_option('float_format', '{:f}'.format)

# warning message 제거
import warnings
warnings.filterwarnings('ignore')

# plot 출력
# %matplotlib inline

# # plot 한글출력
# import matplotlib.font_manager as fm

# for font in fm.fontManager.ttflist:
#     if font.name in ['AppleGothic', 'NanumGothic']:
#         plt.rcParams['font.family'] = font.name
#         break

# plt.rcParams['font.family']

# %%
seat = pd.read_csv('../01.Data_Collection/seat.csv')
show = pd.read_csv('../01.Data_Collection/show.csv')
screen = pd.read_csv('../01.Data_Collection/screen.csv')

print(seat.shape)
print(show.shape)
print(screen.shape)
# Out:
# (58814, 10)
# (58814, 9)
# (58814, 9)

# %%
seat.sample()
# Out:
#        순위    영화명         개봉일  좌석판매율  좌석점유율   좌석수      매출액       누적매출액  관객수  \
# 25675   8  아빠는 딸  2017-04-12  18.3%  0.11%  3147  4100000  5036512395  577
#
#         누적관객수
# 25675  644452

# %%
show.sample()
# Out:
#        순위  영화명         개봉일  상영횟수   상영점유율     매출액        누적매출액  관객수    누적관객수
# 30388  15  장산범  2017-08-17     5  0.044%  240000  10340308083   35  1306203

# %%
screen.sample()
# Out:
#        순위 영화명         개봉일  스크린수 스크린점유율     매출액      누적매출액  관객수  누적관객수
# 51757  12  왓칭  2019-04-17     5   0.2%  250000  462772262   32  55272

# %%
seat.dtypes
# Out:
# 순위         int64
# 영화명       object
# 개봉일       object
# 좌석판매율     object
# 좌석점유율     object
# 좌석수        int64
# 매출액        int64
# 누적매출액      int64
# 관객수        int64
# 누적관객수      int64
# 점유율집계일    object
# dtype: object

# %%
# 데이터 집계 날짜 넣기
date = datetime.date(2014, 12, 31)
str_date = date.isoformat()

# seat
rank_date = []
for rank in seat['순위']:
    if rank == 1: date += datetime.timedelta(days=1)
    rank_date.append(date)
    
seat['점유율집계일'] = rank_date
# Out:
#        순위                    영화명         개봉일   좌석판매율   좌석점유율     좌석수  \
# 0       1                   국제시장  2014-12-17   78.0%  34.99%  964153
# 1       2                   기술자들  2014-12-24   57.9%  10.05%  276896
# 2       3        님아, 그 강을 건너지 마오  2014-11-27   67.2%   9.66%  266197
# 3       4          개를 훔치는 완벽한 방법  2014-12-31   48.1%   2.85%   78410
# 4       5                    상의원  2014-12-24   46.6%   2.22%   61095
# 5       6           더 테너 리리코 스핀토  2014-12-31   18.9%   1.63%   44800
# 6       7     뽀로로 극장판 눈요정 마을 대모험         NaN   51.8%   0.39%   10741
# 7       8         그 사람 그 사랑 그 세상  2014-11-20   45.9%    0.1%    2621
# 8       9                   쿼바디스  2014-12-10   24.6%   0.08%    2073
# 9      10                     목숨  2014-12-04    9.8%   0.07%    1835
# 10     11                 장군의 아들  1990-06-09   18.4%   0.04%    1132
# 11     12                제자, 옥한흠  2014-10-30   15.9%   0.02%     548
# 12     12                   다이빙벨  2014-10-23   18.2%   0.02%     435
# ...

# %%
seat.groupby('순위')['영화명'].count()

# 데이터 집계 날짜 넣기
date = datetime.date(2014, 12, 31)
date + datetime.timedelta(days=1771)
# Out:
# datetime.date(2019, 11, 6)

# %%
seat[seat['순위'] == 1]
# Out:
#        순위               영화명         개봉일  좌석판매율   좌석점유율      좌석수          매출액  \
# 0       1              국제시장  2014-12-17  78.0%  34.99%   964153   6129982500
# 26      1              국제시장  2014-12-17  49.8%  34.95%   946099   3782877729
# 49      1              국제시장  2014-12-17  62.1%  36.85%  1019537   5102642636
# 72      1              국제시장  2014-12-17  55.4%  37.08%   997317   4437089200
# 93      1              국제시장  2014-12-17  23.1%  35.67%   911388   1558134100
# 119     1              국제시장  2014-12-17  23.2%   35.5%   907915   1550265000
# 150     1              국제시장  2014-12-17  21.5%   34.7%   878197   1398815300
# 176     1              국제시장  2014-12-17  21.5%  34.73%   883411   1413971800
# 209     1              국제시장  2014-12-17  22.7%  35.37%   920952   1663760900
# 240     1              국제시장  2014-12-17  45.9%  37.16%  1010882   3746238400
# 270     1              국제시장  2014-12-17  47.2%  37.05%   980694   3731772100
# ...

# %%
zip(seat['순위'], seat['순위'].shift(1))

# %%
same_rank = []
for i, ranks in enumerate(zip(seat['순위'], seat['순위'].shift(1))):
    if ranks[0] == ranks[1]:
#         if ranks[0] == 1: 
        same_rank.append((i, ranks[0]))
    
[(i, x) for i, x in same_rank if x == 1]

# %%
[(i, x) for i, x in same_rank if x == 1]
# Out:
# []

# %%
# 데이터 집계 날짜 넣기
date = datetime.date(2014, 12, 31)
str_date = date.isoformat()

# show
rank_date = []
for rank in show['순위']:
    if rank == 1: date += datetime.timedelta(days=1)
    rank_date.append(date)
    
show['점유율집계일'] = rank_date

# %%
show.tail()
# Out:
#        순위              영화명         개봉일  상영횟수   상영점유율     매출액        누적매출액  \
# 58809  28     나쁜 녀석들: 더 무비  2019-09-11     1  0.015%    6000  39552792124
# 58810  28   1919유관순-그녀들의조국         NaN     1  0.015%    2000        52000
# 58811  28              이어도         NaN     1  0.015%       0      3763500
# 58812  28  뽀로로 극장판 보물섬 대모험  2019-04-25     1  0.015%   79000   5886383900
# 58813  28               로망  2019-04-03     1  0.015%  750000    591424900
#
#        관객수    누적관객수      점유율집계일
# 58809    1  4573112  2019-11-06
# 58810    1       26  2019-11-06
# 58811    0      799  2019-11-06
# 58812   79   766843  2019-11-06
# 58813  150    80079  2019-11-06

# %%
same_rank = []
for i, ranks in enumerate(zip(show['순위'], show['순위'].shift(1))):
    if ranks[0] == ranks[1]:
#         if ranks[0] == 1: 
        same_rank.append((i, ranks[0]))
    
[(i, x) for i, x in same_rank if x == 1]
# Out:
# []

# %%
# 데이터 집계 날짜 넣기
date = datetime.date(2014, 12, 31)
str_date = date.isoformat()

# screen
rank_date = []
for rank in screen['순위']:
    if rank == 1: date += datetime.timedelta(days=1)
    rank_date.append(date)
    
screen['점유율집계일'] = rank_date

# %%
screen.tail()
# Out:
#        순위        영화명         개봉일  스크린수 스크린점유율      매출액      누적매출액  관객수  \
# 58809  22     영하의 바람  2019-11-14     1   0.1%  2295000    6692000  255
# 58810  22     빨간 마후라         NaN     1   0.1%   204000   17325000  102
# 58811  22  아 백범 김구선생         NaN     1   0.1%    22000    3482000   11
# 58812  22       교회오빠  2019-05-16     1   0.1%    10000  870816710    1
# 58813  22         로망  2019-04-03     1   0.1%   750000  591424900  150
#
#         누적관객수      점유율집계일
# 58809     764  2019-11-08
# 58810    8482  2019-11-08
# 58811    1750  2019-11-08
# 58812  109381  2019-11-08
# 58813   80079  2019-11-08

# %%
same_rank = []
for i, ranks in enumerate(zip(screen['순위'], screen['순위'].shift(1))):
    if ranks[0] == ranks[1]:
#         if ranks[0] == 1: 
        same_rank.append((i, ranks[0]))
    
[(i, x) for i, x in same_rank if x == 1]
# Out:
# [(8392, 1), (54373, 1)]
