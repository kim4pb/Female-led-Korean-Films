# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_row', None)

# %%
screen=pd.read_csv('../01.Data_Collection/screen.csv')
seat=pd.read_csv('../01.Data_Collection/seat.csv')
show=pd.read_csv('../01.Data_Collection/show.csv')

# %%
print('screen', screen.shape)
print('seat', seat.shape)
print('show', show.shape)
# Out:
# screen (58814, 10)
# seat (58814, 11)
# show (58814, 10)

# %%
screen.head(40)
# Out:
#     순위                 영화명         개봉일  스크린수 스크린점유율         매출액        누적매출액  \
# 0    1                국제시장  2014-12-17   838  38.9%  1398815300  65049374061
# 1    2     님아, 그 강을 건너지 마오  2014-11-27   428  19.9%   215772700  34895020079
# 2    3                기술자들  2014-12-24   335  15.5%   183656500  18261732983
# 3    4                 워킹걸  2015-01-07   296  13.7%   110945200    143770200
# 4    5       개를 훔치는 완벽한 방법  2014-12-31   102   4.7%    31209900   1393378865
# 5    6                 상의원  2014-12-24    51   2.4%    11700500   6125360064
# 6    7        더 테너 리리코 스핀토  2014-12-31    23   1.1%     7458000    355714641
# 7    8  뽀로로 극장판 눈요정 마을 대모험         NaN    21   1.0%     1430500   1252084900
# 8    9                  설해  2015-01-08    12   0.6%     4867000     15046000
# 9    9                쿼바디스  2014-12-10    12   0.6%     1391000    131031900
# 10  11                  목숨  2014-12-04     9   0.4%      503000    279444600
# ...

# %%
seat.head(40)
# Out:
#     순위                 영화명         개봉일   좌석판매율  좌석점유율     좌석수         매출액  \
# 0    1                국제시장  2014-12-17   21.5%  34.7%  878197  1398815300
# 1    2     님아, 그 강을 건너지 마오  2014-11-27   16.9%  6.95%  175899   215772700
# 2    3                기술자들  2014-12-24   18.2%  5.21%  131812   183656500
# 3    4                 워킹걸  2015-01-07   11.1%  5.07%  128267   110945200
# 4    5       개를 훔치는 완벽한 방법  2014-12-31   19.2%  0.88%   22259    31209900
# 5    6                 상의원  2014-12-24   18.3%  0.34%    8606    11700500
# 6    7  뽀로로 극장판 눈요정 마을 대모험         NaN    5.1%  0.24%    5964     1430500
# 7    8        더 테너 리리코 스핀토  2014-12-31   25.2%  0.16%    3931     7458000
# 8    9                  설해  2015-01-08   26.0%  0.11%    2690     4867000
# 9   10                쿼바디스  2014-12-10    7.2%   0.1%    2633     1391000
# 10  11        고종황제와 의사 안중근         NaN   57.2%  0.05%    1200     1372000
# 11  11      그 사람 그 사랑 그 세상  2014-11-20    5.0%  0.05%    1319      434000
# ...

# %%
show.head(40)
# Out:
#     순위                    영화명         개봉일  상영횟수    상영점유율         매출액  \
# 0    1                   국제시장  2014-12-17  4650  45.651%  6129982500
# 1    2        님아, 그 강을 건너지 마오  2014-11-27  1979  19.429%  1479015600
# 2    3                   기술자들  2014-12-24  1886  18.516%  1299883700
# 3    4          개를 훔치는 완벽한 방법  2014-12-31   650   6.381%   299346400
# 4    5                    상의원  2014-12-24   491    4.82%   230484800
# 5    6           더 테너 리리코 스핀토  2014-12-31   367   3.603%    69620500
# 6    7     뽀로로 극장판 눈요정 마을 대모험         NaN    83   0.815%    27846600
# 7    8                   쿼바디스  2014-12-10    19   0.187%     4046900
# 8    9         그 사람 그 사랑 그 세상  2014-11-20    14   0.137%     9467000
# 9   10                     목숨  2014-12-04    10   0.098%     1399500
# 10  11                제자, 옥한흠  2014-10-30     5   0.049%      687000
# 11  12                   파티51  2014-12-11     4   0.039%      225000
# 12  12                 장군의 아들  1990-06-09     4   0.039%      416000
# ...

# %%
seat.isnull().sum()
# Out:
# 순위           0
# 영화명          0
# 개봉일       5515
# 좌석판매율        0
# 좌석점유율        0
# 좌석수          0
# 매출액          0
# 누적매출액        0
# 관객수          0
# 누적관객수        0
# 점유율집계일       0
# dtype: int64

# %%
show.isnull().sum()
# Out:
# 순위           0
# 영화명          0
# 개봉일       5515
# 상영횟수         0
# 상영점유율        0
# 매출액          0
# 누적매출액        0
# 관객수          0
# 누적관객수        0
# 점유율집계일       0
# dtype: int64

# %%
screen.isnull().sum()
# Out:
# 순위           0
# 영화명          0
# 개봉일       5515
# 스크린수         0
# 스크린점유율       0
# 매출액          0
# 누적매출액        0
# 관객수          0
# 누적관객수        0
# 점유율집계일       0
# dtype: int64

# %% [markdown]
# 스크린 점유율 1%~ 0% 인 영화들이 개봉일이 정보가 없음

# %%
screen[screen['개봉일'].isnull()]
# Out:
#        순위                                                영화명  개봉일  스크린수  \
# 7       8                                 뽀로로 극장판 눈요정 마을 대모험  NaN    21
# 16     16                                           민우씨 오는 날  NaN     2
# 20     19                                       고종황제와 의사 안중근  NaN     1
# 32      7                                 뽀로로 극장판 눈요정 마을 대모험  NaN    41
# 46     17                                       고종황제와 의사 안중근  NaN     1
# 47     17                             1월 단편 상상극장 – 맛있게 먹겠습니다  NaN     1
# 49     17                                           민우씨 오는 날  NaN     1
# 63      7                                 뽀로로 극장판 눈요정 마을 대모험  NaN    38
# 77     16                                           민우씨 오는 날  NaN     1
# 81     16                                 2015 우수 단편영화 상영 01  NaN     1
# 89      7                                 뽀로로 극장판 눈요정 마을 대모험  NaN    64
# 97     15                                           민우씨 오는 날  NaN     2
# ...

# %%
screen.head(1)
# Out:
#    순위   영화명         개봉일  스크린수 스크린점유율         매출액        누적매출액     관객수  \
# 0   1  국제시장  2014-12-17   838  38.9%  1398815300  65049374061  188721
#
#      누적관객수      점유율집계일
# 0  8362611  2015-01-01

# %%
seat.head(1)
# Out:
#    순위   영화명         개봉일  좌석판매율  좌석점유율     좌석수         매출액        누적매출액  \
# 0   1  국제시장  2014-12-17  21.5%  34.7%  878197  1398815300  65049374061
#
#       관객수    누적관객수      점유율집계일
# 0  188721  8362611  2015-01-01

# %%
# 머지를위해 형변환  
screen['순위'] = screen['순위'].apply(lambda x: str(x))
screen['스크린수'] = screen['스크린수'].apply(lambda x: str(x))
screen['매출액'] = screen['매출액'].apply(lambda x: str(x))
screen['누적매출액'] = screen['누적매출액'].apply(lambda x: str(x))
screen['관객수'] = screen['관객수'].apply(lambda x: str(x))

# %%
screen['누적관객수'] = screen['누적관객수'].apply(lambda x: str(x))

# %%
screen.dtypes
# Out:
# 순위        object
# 영화명       object
# 개봉일       object
# 스크린수      object
# 스크린점유율    object
# 매출액       object
# 누적매출액     object
# 관객수       object
# 누적관객수     object
# 점유율집계일    object
# dtype: object

# %%
# 형변환
show['순위'] = show['순위'].apply(lambda x: str(x))
show['상영횟수'] = show['상영횟수'].apply(lambda x: str(x))
show['매출액'] = show['매출액'].apply(lambda x: str(x))
show['누적매출액'] = show['누적매출액'].apply(lambda x: str(x))
show['관객수'] = show['관객수'].apply(lambda x: str(x))
show['누적관객수'] = show['누적관객수'].apply(lambda x: str(x))

# %%
show.dtypes
# Out:
# 순위        object
# 영화명       object
# 개봉일       object
# 상영횟수      object
# 상영점유율     object
# 매출액       object
# 누적매출액     object
# 관객수       object
# 누적관객수     object
# 점유율집계일    object
# dtype: object

# %%
# 머지 작업
screen_show = screen.merge(show, how='inner' , left_on=['개봉일','누적관객수','영화명', '매출액', '관객수', '누적매출액']
                                            , right_on=['개봉일', '누적관객수','영화명', '매출액', '관객수', '누적매출액'])

# %%
screen_show.head()
# Out:
#   순위_x              영화명         개봉일 스크린수 스크린점유율         매출액        누적매출액  \
# 0    1             국제시장  2014-12-17  838  38.9%  1398815300  65049374061
# 1    2  님아, 그 강을 건너지 마오  2014-11-27  428  19.9%   215772700  34895020079
# 2    3             기술자들  2014-12-24  335  15.5%   183656500  18261732983
# 3    4              워킹걸  2015-01-07  296  13.7%   110945200    143770200
# 4    5    개를 훔치는 완벽한 방법  2014-12-31  102   4.7%    31209900   1393378865
#
#       관객수    누적관객수    점유율집계일_x 순위_y  상영횟수    상영점유율    점유율집계일_y
# 0  188721  8362611  2015-01-01    1  4164  53.092%  2015-01-07
# 1   29657  4478450  2015-01-01    2  1351  17.226%  2015-01-07
# 2   24046  2360507  2015-01-01    4   955  12.176%  2015-01-07
# 3   14281    18503  2015-01-01    3   964  12.291%  2015-01-07
# 4    4262   183398  2015-01-01    5   181   2.308%  2015-01-07

# %%
# 필요없는 컬럼 삭제 
# screen_show.drop(['순위_x', '점유율집계일_x', '순위_y', '개봉일_y', '점유율집계일_y'], axis='columns', inplace=True)

# 점유율집계일이 필요하다는 피드백을 받고 삭제안함.

# %%
# screen_show.drop(['누적관객수_x', '누적관객수_y'], axis='columns', inplace=True)

# %%
screen_show.head()
# Out:
#   스크린_순위              영화명         개봉일 스크린수 스크린점유율         매출액        누적매출액  \
# 0      1             국제시장  2014-12-17  838  38.9%  1398815300  65049374061
# 1      2  님아, 그 강을 건너지 마오  2014-11-27  428  19.9%   215772700  34895020079
# 2      3             기술자들  2014-12-24  335  15.5%   183656500  18261732983
# 3      4              워킹걸  2015-01-07  296  13.7%   110945200    143770200
# 4      5    개를 훔치는 완벽한 방법  2014-12-31  102   4.7%    31209900   1393378865
#
#       관객수    누적관객수  스크린_점유율집계일 상영_순위  상영횟수    상영점유율   상영_점유율집계일
# 0  188721  8362611  2015-01-01     1  4164  53.092%  2015-01-07
# 1   29657  4478450  2015-01-01     2  1351  17.226%  2015-01-07
# 2   24046  2360507  2015-01-01     4   955  12.176%  2015-01-07
# 3   14281    18503  2015-01-01     3   964  12.291%  2015-01-07
# 4    4262   183398  2015-01-01     5   181   2.308%  2015-01-07

# %%
# 이름 변경
screen_show.rename(columns={'순위_x': '스크린_순위'}, inplace=True)
screen_show.rename(columns={'순위_y': '상영_순위'}, inplace=True)
screen_show.rename(columns={'점유율집계일_y': '상영_점유율집계일'}, inplace=True)
screen_show.rename(columns={'점유율집계일_x': '스크린_점유율집계일'}, inplace=True)

# %%
# screen_show.drop(['누적관객수_y', '개봉일_y'], axis='columns', inplace=True)

# %%
seat.head(1)
# Out:
#    순위   영화명         개봉일  좌석판매율  좌석점유율     좌석수         매출액        누적매출액  \
# 0   1  국제시장  2014-12-17  21.5%  34.7%  878197  1398815300  65049374061
#
#       관객수    누적관객수      점유율집계일
# 0  188721  8362611  2015-01-01

# %%
seat.dtypes
# Out:
# 순위         int64
# 영화명       object
# 개봉일       object
# 좌석판매율     object
# 좌석점유율     object
# 좌석수        int64
# 매출액        int64
# 누적매출액      int64
# 관객수        int64
# 누적관객수      int64
# 점유율집계일    object
# dtype: object

# %%
screen_show.dtypes
# Out:
# 스크린_순위        object
# 영화명           object
# 개봉일           object
# 스크린수          object
# 스크린점유율        object
# 매출액           object
# 누적매출액         object
# 관객수           object
# 누적관객수         object
# 스크린_점유율집계일    object
# 상영_순위         object
# 상영횟수          object
# 상영점유율         object
# 상영_점유율집계일     object
# dtype: object

# %%
seat['좌석수'] = seat['좌석수'].apply(lambda x: str(x))
seat['매출액'] = seat['매출액'].apply(lambda x: str(x))
seat['누적매출액'] = seat['누적매출액'].apply(lambda x: str(x))
seat['관객수'] = seat['관객수'].apply(lambda x: str(x))
seat['누적관객수'] = seat['누적관객수'].apply(lambda x: str(x))

# %%
print('seat', seat.shape)
print('screen_show', screen_show.shape)
# Out:
# seat (58814, 11)
# screen_show (61010, 14)

# %%
screen_show_seat = screen_show.merge(seat, how='inner' , left_on=['개봉일','영화명', '매출액', '관객수', '누적매출액', '누적관객수']
                                            , right_on=['개봉일','영화명', '매출액', '관객수', '누적매출액', '누적관객수'])

# %%
#screen_show_seat.drop(['개봉일'], axis='columns', inplace=True)

# %%
screen_show_seat.head(1)
# Out:
#   스크린_순위   영화명         개봉일 스크린수 스크린점유율         매출액        누적매출액     관객수  \
# 0      1  국제시장  2014-12-17  838  38.9%  1398815300  65049374061  188721
#
#      누적관객수  스크린_점유율집계일 상영_순위  상영횟수    상영점유율   상영_점유율집계일  순위  좌석판매율  좌석점유율  \
# 0  8362611  2015-01-01     1  4164  53.092%  2015-01-07   1  21.5%  34.7%
#
#       좌석수      점유율집계일
# 0  878197  2015-01-01

# %%
# screen_show_seat.drop(['누적관객수'], axis='columns', inplace=True)

# %%
seat.head(1)
# Out:
#     영화명         개봉일  좌석판매율  좌석점유율     좌석수         매출액        누적매출액     관객수  \
# 0  국제시장  2014-12-17  21.5%  34.7%  878197  1398815300  65049374061  188721
#
#      누적관객수
# 0  8362611

# %%
# screen_show_seat.drop(['개봉일'], axis='columns', inplace=True)

# %%
# 이름 변경
screen_show_seat.rename(columns={'순위': '좌석_순위'}, inplace=True)
screen_show_seat.rename(columns={'점유율집계일': '좌석_점유율집계일'}, inplace=True)

# %%
#screen_show_seat.rename(columns={'개봉일_x': '개봉일'}, inplace=True)

# %%
# 재정렬
screen_show_seat = screen_show_seat[['영화명','개봉일','관객수', '누적관객수','매출액', '누적매출액','상영_순위', '상영점유율', '상영횟수', '상영_점유율집계일', '좌석_순위','좌석판매율', '좌석점유율', '좌석수','좌석_점유율집계일','스크린_순위','스크린점유율', '스크린수','스크린_점유율집계일' ]]

# %%
screen_show_seat.head(1)
# Out:
#     영화명         개봉일     관객수    누적관객수         매출액        누적매출액 상영_순위    상영점유율  \
# 0  국제시장  2014-12-17  188721  8362611  1398815300  65049374061     1  53.092%
#
#    상영횟수   상영_점유율집계일  좌석_순위  좌석판매율  좌석점유율     좌석수   좌석_점유율집계일 스크린_순위 스크린점유율  \
# 0  4164  2015-01-07      1  21.5%  34.7%  878197  2015-01-01      1  38.9%
#
#   스크린수  스크린_점유율집계일
# 0  838  2015-01-01

# %%
# screen_show_seat.drop(['개봉일_x'], axis='columns', inplace=True)

# %% [markdown]
# 만약 상영시간표를 시간대별로 등급을 준다면.... 데이터 안에 요금이 있으니 이 요금들을 사용해서 등급을 나누면 어떨까요???
# - 예시: 7000-9000원 별로, 10000만원 좋음 등등...
# - 참조: cdv 시간표별 요금( 다 다름 ...)

# %%
cgv.head(5)
# Out:
#    Unnamed: 0        상영일자           상영관                               1회  \
# 0           0  2018-01-01           01관  07:50,  신과함께-죄와 벌(디지털),  7,000원
# 1           1  2018-01-01           02관     07:10,  위대한 쇼맨(디지털),  9,000원
# 2           2  2018-01-01           03관       06:30,  1987(디지털),  9,000원
# 3           3  2018-01-01  04관(SCREENX)       07:30,  1987(디지털),  7,000원
# 4           4  2018-01-01           05관  06:50,  신과함께-죄와 벌(디지털),  7,000원
#
#                                  2회                                3회  \
# 0  10:40,  신과함께-죄와 벌(디지털),  11,000원  13:30,  신과함께-죄와 벌(디지털),  11,000원
# 1       09:20,  광인옥한흠(디지털),  7,000원  11:30,  신과함께-죄와 벌(디지털),  11,000원
# 2        09:10,  1987(디지털),  9,000원       11:50,  1987(디지털),  11,000원
# 3         10:10,  원더(디지털),  11,000원         12:40,  원더(디지털),  11,000원
# 4   09:40,  신과함께-죄와 벌(디지털),  7,000원  12:30,  신과함께-죄와 벌(디지털),  11,000원
#
#                                  4회                                5회  \
# ...

# %%
screen_show_seat.to_csv('../01.Data_Collection/screen_show_seat.csv', index=False)
