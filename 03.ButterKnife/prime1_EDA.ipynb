# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns


# 전체 컬럼, 전체 행, 전체 숫자 출력

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('float_format', '{:f}'.format)

# warning message 제거

import warnings
warnings.filterwarnings('ignore')

# plot 출력

# %matplotlib inline

# plot 한글출력

import matplotlib.font_manager as fm

for font in fm.fontManager.ttflist:
    if font.name in ['AppleGothic', 'NanumGothic']:
        plt.rcParams['font.family'] = font.name
        break

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
import plotly.graph_objects as go
import plotly.express as px

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
prime1 = pd.read_csv('prime_group1.csv')
print(prime1.shape)
# Out:
# (253, 2)

# %%
prime1.head()
# Out:
#               영화명       총공급좌석수
# 0              22 12455.000000
# 1          가을 우체국 32500.000000
# 2  개: dog eat dog  5925.000000
# 3           거미의 땅  8692.000000
# 4             거짓말 30925.000000

# %% [markdown]
# # prime1 eda 시작

# %%
prime1['총공급좌석수'].hist(bins=50)

# %%
films = pd.read_csv('../01.Data_Collection/films_updated.csv')
print(films.shape)
films.sample()
# Out:
# (685, 38)
#        영화명      영화코드         개봉일 대표국적  국적     장르        등급 영화형태     영화구분  \
# 180  탐욕의 별  20162684  2016-04-27   한국  한국  다큐멘터리  15세이상관람가   장편  독립/예술영화
#
#            제작사     배급사  상영횟수  전국스크린수          전국매출액  전국관객수    서울매출액  서울관객수  \
# 180  스파이럴 프로젝트  ㈜인디스토리   120       9 4461500.000000    684  3101500    468
#
#      F-rated   감독 대표감독      감독코드 감독성별 감독_대표역할  \
# 180        0  공귀현  공귀현  20112654   남자      감독
#
#                                 감독필모   작가 대표작가 대표작가(필명)      작가코드 작가성별  \
# 180  탐욕의 별|별이 빛나는 밤|철암 계곡의 혈투|U.F.O.  공귀현  공귀현      공귀현  20112654   남자
#
#     작가_대표역할                             작가필모   배우 주연배우  배역명      배우코드 배우성별  \
# 180      감독  탐욕의 별|별이 빛나는 밤|철암 계곡의 혈투|U.F.O.  김의성  김의성  NaN  10005383   남자
#
#     배우_대표역할                                               배우필모
# 180      배우  특송|어쩌다, 결혼|창궐|도청(가제)|골든슬럼버|강철비|돌멩이|더 킹|당신자신과 당...

# %%
# 장르: 애니메이션
films[films['영화명']=='최강전사 미니특공대: 영웅의 탄생']
# Out:
#                     영화명      영화코드         개봉일 대표국적  국적     장르     등급 영화형태  \
# 149  최강전사 미니특공대: 영웅의 탄생  20159657  2016-02-04   한국  한국  애니메이션  전체관람가   장편
#
#      영화구분         제작사         배급사  상영횟수  전국스크린수            전국매출액   전국관객수  \
# 149  일반영화  (주)삼지애니메이션  (주)삼지애니메이션  4914     349 866704200.000000  115704
#
#          서울매출액  서울관객수  F-rated   감독 대표감독      감독코드 감독성별 감독_대표역할  \
# 149  172514300  22357        1  이영준  이영준  20186877   남자      감독
#
#                                                   감독필모        작가 대표작가  \
# 149  미니특공대X|파워배틀 와치카: 와치가면의 역습|부릉! 부릉! 브루미즈: 스피더의 모...  최인희, 김수훈  최인희
#
#     대표작가(필명)      작가코드 작가성별   작가_대표역할  \
# 149      최인희  20228888   여자  시나리오(각본)
#
#                                                   작가필모           배우 주연배우 배역명  \
# 149  최강전사 미니특공대: 영웅의 탄생|안녕, 전우치! 도술로봇대결전|최강전사 미니특공대...  엄상현,양정화,전태열  엄상현   -
#
#          배우코드 배우성별 배우_대표역할                                               배우필모
# ...

# %%
#films-kid

kid_ = films[films.장르 != '애니매이션']

# %%
films[films['장르']=='애니메이션']
# Out:
#                            영화명      영화코드         개봉일 대표국적  국적     장르  \
# 8                      생각보다 맑은  20145202  2015-01-22   한국  한국  애니메이션
# 11     최강전사 미니특공대 : 새로운 악당의 습격  20156441  2015-02-05   한국  한국  애니메이션
# 88                    슈퍼레이서 엔지  20154323  2015-09-10   한국  한국  애니메이션
# 97            안녕, 전우치! 도술로봇대결전  20153801  2015-10-08   한국  한국  애니메이션
# 115      꾸루꾸루와 친구들: 무지개 나무의 비밀  20158682  2015-11-19   한국  한국  애니메이션
# 127         뽀로로 극장판 컴퓨터 왕국 대모험  20156807  2015-12-10   한국  한국  애니메이션
# 129                        타이밍  20141598  2015-12-10   한국  한국  애니메이션
# 143      극장판 꼬마버스 타요의 에이스 구출작전  20150566  2016-01-21   한국  한국  애니메이션
# 149         최강전사 미니특공대: 영웅의 탄생  20159657  2016-02-04   한국  한국  애니메이션
# 171       극장판 프랭키와 친구들: 생명의 나무  20162431  2016-04-13   한국  한국  애니메이션
# 183                 극장판 안녕 자두야  20162704  2016-05-04   한국  한국  애니메이션
# 219                     슈퍼 프렌즈  20165961  2016-08-10   한국  한국  애니메이션
# 220  파워배틀 와치카 미니카 배틀리그: 불꽃의 질주  20165981  2016-08-17   한국  한국  애니메이션
# ...

# %%
#애니매이션 제외한 값
kid=films[films.장르!='애니메이션']

# %%
kid[kid['영화명']=='최강전사 미니특공대: 영웅의 탄생']
# Out:
# Empty DataFrame
# Columns: [영화명, 영화코드, 개봉일, 대표국적, 국적, 장르, 등급, 영화형태, 영화구분, 제작사, 배급사, 상영횟수, 전국스크린수, 전국매출액, 전국관객수, 서울매출액, 서울관객수, F-rated, 감독, 대표감독, 감독코드, 감독성별, 감독_대표역할, 감독필모, 작가, 대표작가, 대표작가(필명), 작가코드, 작가성별, 작가_대표역할, 작가필모, 배우, 주연배우, 배역명, 배우코드, 배우성별, 배우_대표역할, 배우필모]
# Index: []

# %%
df = prime1.merge(films, how='left', on='영화명')
print(df.shape)
df.sample()
# Out:
# (253, 39)
#        영화명      총공급좌석수            영화코드         개봉일 대표국적  국적        장르  \
# 122  사월의 끝 3025.000000 20163842.000000  2017-09-14   한국  한국  미스터리,스릴러
#
#           등급 영화형태     영화구분   제작사       배급사      상영횟수   전국스크린수          전국매출액  \
# 122  청소년관람불가   장편  독립/예술영화  코라필름  (주)비엠컬쳐스 66.000000 6.000000 3389900.000000
#
#          전국관객수          서울매출액      서울관객수  F-rated   감독 대표감독            감독코드  \
# 122 519.000000 2081900.000000 257.000000 1.000000  김광복  김광복 20251849.000000
#
#     감독성별 감독_대표역할   감독필모   작가 대표작가 대표작가(필명)            작가코드 작가성별 작가_대표역할  \
# 122   남자      감독  사월의 끝  김광복  김광복      김광복 20251849.000000   남자      감독
#
#       작가필모                                  배우 주연배우  배역명            배우코드 배우성별  \
# 122  사월의 끝  박지수,이빛나,장소연,윤근,최나영,최수복,이은지,연송하,이양희  박지수  나옥분 20167120.000000   여자
#
#     배우_대표역할                                               배우필모
# 122      배우  사월의 끝|네버다이 버터플라이|마이 라띠마|나는 아직도 당신이 궁금하여 자다가도 일...

# %%
df_kid = kid.merge(films, how='left', on='영화명')
print(df_kid.shape)
df_kid.sample()
# Out:
# (651, 75)
#       영화명    영화코드_x       개봉일_x 대표국적_x 국적_x   장르_x      등급_x 영화형태_x   영화구분_x  \
# 411  공동정범  20169443  2018-01-25     한국   한국  다큐멘터리  15세이상관람가     장편  독립/예술영화
#
#                       제작사_x             배급사_x  상영횟수_x  전국스크린수_x  \
# 411  성소수문화환경을 위한 모임 '연분홍치마'  (주)엣나인필름,(주)시네마달    1188        73
#
#             전국매출액_x  전국관객수_x   서울매출액_x  서울관객수_x  F-rated_x     감독_x 대표감독_x  \
# 411 82372300.000000    11198  55193100     7291          0  김일란,이혁상    이혁상
#
#        감독코드_x 감독성별_x 감독_대표역할_x  \
# 411  10058080     남자        감독
#
#                                                감독필모_x 작가_x 대표작가_x 대표작가(필명)_x  \
# 411  공동정범|노라노|두 개의 문|종로의 기적|레즈비언 정치도전기|3xFTM|울리불리다이어트  이혁상    이혁상        이혁상
#
#        작가코드_x 작가성별_x 작가_대표역할_x  \
# 411  10058080     남자        감독
#
#                                                작가필모_x  \
# 411  공동정범|노라노|두 개의 문|종로의 기적|레즈비언 정치도전기|3xFTM|울리불리다이어트
#
#                                         배우_x 주연배우_x 배역명_x    배우코드_x 배우성별_x  \
# ...

# %%
# 전체 영화
sns.scatterplot(x='총공급좌석수', y='전국관객수', data=df)

# %%
# 키드
sns.scatterplot(x='총공급좌석수_x', y='전국관객수_x', data=df_kid)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-f07523d5d082> in <module>
#       1 # 키드
# ----> 2 sns.scatterplot(x='총공급좌석수_x', y='전국관객수_x', data=df_kid)
#
# /anaconda3/lib/python3.7/site-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#    1333         x_bins=x_bins, y_bins=y_bins,
#    1334         estimator=estimator, ci=ci, n_boot=n_boot,
# -> 1335         alpha=alpha, x_jitter=x_jitter, y_jitter=y_jitter, legend=legend,
#    1336     )
#    1337
#
# ...

# %%
px.scatter(df, x='총공급좌석수', y='전국관객수'
          , hover_name='영화명'
          )
# Out:
# <div>
#
#
#             <div id="8a7bcc9b-616b-4fb5-9564-0d1ee4633b26" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8a7bcc9b-616b-4fb5-9564-0d1ee4633b26")) {
#                     Plotly.newPlot(
#                         '8a7bcc9b-616b-4fb5-9564-0d1ee4633b26',
# ...

# %% [markdown]
# - 전국 관객수*총 공급좌석수의 상위 랭크들은 대부분 애니. (특이점: sm 영화)
# - 여성서사 영화: 문영, 불온한 당신, 박화영, 선희와 슬기,

# %%
px.scatter(df, x='총공급좌석수', y='전국매출액'
          , hover_name='영화명'
          )
# Out:
# <div>
#
#
#             <div id="a494858f-5ff5-48bd-b674-cf1379420a67" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a494858f-5ff5-48bd-b674-cf1379420a67")) {
#                     Plotly.newPlot(
#                         'a494858f-5ff5-48bd-b674-cf1379420a67',
# ...

# %%
rate = pd.read_csv('../01.Data_Collection/screen_show_seat_with_filtered_film.csv')
print(rate.shape)
rate.sample()
# Out:
# (40234, 20)
#        Unnamed: 0  스크린점유율순위   영화명         개봉일  스크린수   스크린점유율     매출액  \
# 39123       39123        27  산상수훈  2017-12-07     1 0.000000  263000
#
#            누적매출액  관객수  누적관객수      점유율집계일  좌석판매점유율순위     좌석판매율    좌석점유율  좌석수  \
# 39123  408001350   27  54282  2019-09-01         31 90.000000 0.000000   30
#
#        순위  상영횟수    상영점유율                        개봉n일차  개봉n일차(int)
# 39123  30     1 0.007000  633 days 00:00:00.000000000         633

# %%
rate['개봉n일차(int)'] = rate['개봉n일차'].apply(lambda x: int(x.split()[0]))
rate.sample()
# Out:
#      Unnamed: 0  스크린점유율순위      영화명         개봉일  스크린수   스크린점유율    매출액  \
# 375         375        12  미라클 여행기  2015-01-15     3 0.100000  22000
#
#         누적매출액  관객수  누적관객수      점유율집계일  좌석판매점유율순위    좌석판매율    좌석점유율  좌석수  순위  \
# 375  15034500    3   2499  2015-02-15         15 1.000000 0.010000  305  15
#
#      상영횟수    상영점유율                       개봉n일차  개봉n일차(int)
# 375     3 0.038000  31 days 00:00:00.000000000          31

# %%
rate[rate['영화명'] == '문영']['개봉일']
# Out:
# 12452    2017-01-12
# 12525    2017-01-12
# 14332    2017-01-12
# 14560    2017-01-12
# 14709    2017-01-12
# 14875    2017-01-12
# 14908    2017-01-12
# 14911    2017-01-12
# 14935    2017-01-12
# 14946    2017-01-12
# 14964    2017-01-12
# 14997    2017-01-12
# 15022    2017-01-12
# 15034    2017-01-12
# 15060    2017-01-12
# 15071    2017-01-12
# 15086    2017-01-12
# 15112    2017-01-12
# 15145    2017-01-12
# 15165    2017-01-12
# 15172    2017-01-12
# 15192    2017-01-12
# 15195    2017-01-12
# 15217    2017-01-12
# 15233    2017-01-12
# 15241    2017-01-12
# 15262    2017-01-12
# 15278    2017-01-12
# 15302    2017-01-12
# 15312    2017-01-12
# 15337    2017-01-12
# 15352    2017-01-12
# 15367    2017-01-12
# 15376    2017-01-12
# 15391    2017-01-12
# 15413    2017-01-12
# 15430    2017-01-12
# 15459    2017-01-12
# 15473    2017-01-12
# 15481    2017-01-12
# 15510    2017-01-12
# 15515    2017-01-12
# 15536    2017-01-12
# 15565    2017-01-12
# 15585    2017-01-12
# ...

# %%
df.corr()
# Out:
#           총공급좌석수     영화코드     상영횟수    전국스크린수     전국매출액     전국관객수     서울매출액  \
# 총공급좌석수  1.000000 0.112002 0.428140  0.276147  0.251443  0.242418  0.367414
# 영화코드    0.112002 1.000000 0.145268  0.180524  0.074784  0.067500  0.041070
# 상영횟수    0.428140 0.145268 1.000000  0.924662  0.930370  0.928204  0.822029
# 전국스크린수  0.276147 0.180524 0.924662  1.000000  0.862383  0.861635  0.726112
# 전국매출액   0.251443 0.074784 0.930370  0.862383  1.000000  0.998643  0.898101
# 전국관객수   0.242418 0.067500 0.928204  0.861635  0.998643  1.000000  0.892722
# 서울매출액   0.367414 0.041070 0.822029  0.726112  0.898101  0.892722  1.000000
# 서울관객수   0.349833 0.021227 0.818893  0.719115  0.898932  0.896964  0.995375
# F-rated 0.213138 0.033517 0.039364 -0.030108 -0.026939 -0.032537 -0.006471
# 감독코드    0.149409 0.170074 0.139327  0.090536  0.118221  0.112473  0.146399
# 작가코드    0.107572 0.122380 0.105267  0.065376  0.120196  0.119759  0.144515
# ...

# %%
data = rate.loc[rate['영화명'] == '최강전사 미니특공대: 영웅의 탄생', ['개봉n일차(int)', '좌석판매율']]

sns.lineplot(x='개봉n일차(int)', y='좌석판매율', data=data)
plt.xticks(rotation=45)
plt.show()

# %%
data = rate.loc[rate['영화명'] == '불온한 당신', ['개봉n일차(int)', '좌석판매율']]

sns.lineplot(x='개봉n일차(int)', y='좌석판매율', data=data)
plt.xticks(rotation=45)
plt.show()

# %%
data = rate.loc[rate['영화명'] == '문영', ['개봉n일차(int)', '좌석판매율']]

sns.lineplot(x='개봉n일차(int)', y='좌석판매율', data=data)
plt.xticks(rotation=45)
plt.show()

# %%
data = rate.loc[rate['영화명'] == '박화영', ['개봉n일차(int)', '좌석판매율']]

sns.lineplot(x='개봉n일차(int)', y='좌석판매율', data=data)
plt.xticks(rotation=45)
plt.show()

# %%
data = rate.loc[rate['영화명'] == '박화영', ['개봉n일차(int)','관객수', '좌석수']]

plt.figure(figsize=[16, 6])
sns.barplot(x='개봉n일차(int)', y='좌석수', data=data, color='black')
plt.xticks(rotation=45)

sns.barplot(x='개봉n일차(int)', y='관객수', data=data, color='y')
plt.xticks(rotation=45)

plt.show()

# %%
data = rate.loc[rate['영화명'] == '최강전사 미니특공대: 영웅의 탄생', ['개봉n일차(int)','관객수', '좌석수']]

plt.figure(figsize=[16, 6])
sns.barplot(x='개봉n일차(int)', y='좌석수', data=data, color='black')
plt.xticks(rotation=45)

sns.barplot(x='개봉n일차(int)', y='관객수', data=data, color='y')
plt.xticks(rotation=45)

plt.show()

# %%
data = rate.loc[rate['영화명'] == '불온한 당신', ['개봉n일차(int)', '좌석수', '관객수']]

plt.figure(figsize=[16, 6])
sns.barplot(x='개봉n일차(int)', y='좌석수', data=data, color='black')
plt.xticks(rotation=45)

# plt.figure(figsize=[16, 6])
sns.barplot(x='개봉n일차(int)', y='관객수', data=data, color='y')
plt.xticks(rotation=45)
plt.show()

# %%
# 애니 제외하고 한번 더 보기.

# %%
weekly_audi = []
for movie in rate['영화명'].unique():

    sum_audi = 0
    for i, row in pd.DataFrame(rate.loc[rate['영화명'] == movie, ['개봉n일차(int)', '관객수']]).iterrows():
    #     print(row['개봉n일차(int)'], row['관객수'])

        if row['개봉n일차(int)'] % 7 == 0:
            n = row['개봉n일차(int)'] // 7
            weekly_audi.append((movie, n + 1, sum_audi))
            sum_audi = 0

        sum_audi += row['관객수']

# %%
data = pd.DataFrame(weekly_audi, columns=['영화명', '개봉n주차', '주차관객수'])
print(data.shape)
data.sample()
# Out:
# (5869, 3)
#         영화명  개봉n주차  주차관객수
# 32  미라클 여행기      8    253

# %%
# data['개봉n주차'].hist()
sns.boxplot(y='개봉n주차', data=data)

# %% [markdown]
# git 천재가 되는 그 날을 위해...언제쯤 될려나...이렇게 글을 써본다... 아샬님....내 컴퓨터 돌려줘요.....

# %% [markdown]
# 내 컴퓨터 살려줘....내 컴퓨터...
